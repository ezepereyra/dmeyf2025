# %% [markdown]
# ## Generacion de la clase_ternaria

# %%
require( "data.table" )

# leo el dataset
dataset <- fread("/content/datasets/competencia_01_crudo.csv" )

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
    "pos" = .I,
    numero_de_cliente,
    periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 ) ]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
    shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente ]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
    ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
    clase_ternaria := "BAJA+1" ]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
    & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
    clase_ternaria := "BAJA+2" ]


# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)
# Out:
# Loading required package: data.table

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  202101   BAJA+1            622
# 2  202101   BAJA+2            825
# 3  202101   CONTINUA       160080
# 4  202102   BAJA+1            831
# 5  202102   BAJA+2           1032
# 6  202102   CONTINUA       160292
# 7  202103   BAJA+1           1039
# 8  202103   BAJA+2            951
# 9  202103   CONTINUA       161119
# 10 202104   BAJA+1            955
# 11 202104   BAJA+2           1130
# 12 202104   CONTINUA       161333
# 13 202105   NA             162783
# 14 202105   BAJA+1           1134
# 15 202106   NA             164313

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Oct 11 11:43:00 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  726089 38.8   1454651    77.7   1454651   77.7
# Vcells 1423194 10.9 169514316  1293.3 211568341 1614.2

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %% [markdown]
# Esta parte lleva varios minutos la primera vez en Google Colab

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: parallel
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings
#
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4923 # también 4921
PARAM$semilla_primigenia <- 99991 # uso distinta semilla para cada experimento

# %%
# training y future
#entreno 202102,202103,202103
PARAM$train <- c(202101, 202102, 202103)
PARAM$train_final <- c(202101, 202102, 202103)
PARAM$future <- c(202104)
PARAM$semilla_kaggle <- 314159

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.1

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower = 8L, upper = 2048L),
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.06),
  makeNumericParam("feature_fraction", lower = 0.45, upper = 0.8),
  makeIntegerParam("num_leaves", lower = 8L, upper = 256L),
  makeIntegerParam("min_data_in_leaf", lower = 10L, upper = 3500L),
  makeNumericParam("lambda_l1", lower = 0.0, upper = 5.0),
  makeNumericParam("lambda_l2", lower = 0.01, upper = 10.0),
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1.0),
  makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 10.0),
  makeNumericParam("min_sum_hessian_in_leaf", lower = 0.001, upper = 8.0),
  makeIntegerParam("max_depth", lower = -1L, upper = 16L),
  makeIntegerParam("max_bin", lower = 63L, upper = 511L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 70 # iteraciones bayesianas

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed, "L'Ecuyer-CMRG")

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# iniciliazo el dataset de realidad, para medir ganancia
realidad_inicializar <- function( pfuture, pparam) {

  # datos para verificar la ganancia
  drealidad <- pfuture[, list(numero_de_cliente, foto_mes, clase_ternaria)]

  particionar(drealidad,
    division= c(3, 7),
    agrupa= "clase_ternaria",
    seed= PARAM$semilla_kaggle
  )

  return( drealidad )
}

# %%
# evaluo ganancia en los datos de la realidad

realidad_evaluar <- function( prealidad, pprediccion) {

  prealidad[ pprediccion,
    on= c("numero_de_cliente", "foto_mes"),
    predicted:= i.Predicted
  ]

  tbl <- prealidad[, list("qty"=.N), list(fold, predicted, clase_ternaria)]

  res <- list()
  res$public  <- tbl[fold==1 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.3
  res$private <- tbl[fold==2 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.7
  res$total <- tbl[predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]

  prealidad[, predicted:=NULL]
  return( res )
}

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/competencia_01.csv.gz", stringsAsFactors= TRUE)

# %% [markdown]
# PRIMERO CORRIJO EL DATA DRIFTING

# %% [markdown]
# Corrijo variables en pesos por el valor del dólar

# %%
library(data.table)

# Definir los Factores de Conversión (Tipo de Dólar de Compra y Venta)
FACTORES_DOLAR <- data.table(
    foto_mes = c(202101, 202102, 202103, 202104, 202105, 202106),
    dolar_compra = c(84.51, 87.62, 90.20, 91.93, 93.23, 94.09),
    dolar_venta = c(90.79, 93.73, 96.31, 98.21, 99.50, 100.37)
)

# Clasificar las Variables por Naturaleza Financiera

# A. Ingresos, Saldos, Límites, Inversiones, Rentabilidad (ACTIVO / PODER DE COMPRA)
# USAR Dólar de COMPRA (menor valor)
vars_compra <- c(
    "mrentabilidad", "mrentabilidad_annual", "mactivos_margen", "mpasivos_margen",
    "mcuenta_corriente_adicional", "mcuenta_corriente", "mcaja_ahorro",
    "mcaja_ahorro_adicional", "mcuentas_saldo", "mpayroll", "mpayroll2",
    "mprestamos_personales", "mprestamos_prendarios", "mprestamos_hipotecarios",
    "mplazo_fijo_pesos", "minversion1_pesos", "minversion2",
    "mtransferencias_recibidas", "mextraccion_autoservicio", "mcheques_depositados",
    "Master_mfinanciacion_limite", "Master_msaldototal", "Master_msaldopesos",
    "Master_mlimitecompra", "Master_madelantopesos", "Master_mpagado",
    "Master_mpagospesos", "Master_mpagominimo",
    "Visa_mfinanciacion_limite", "Visa_msaldototal", "Visa_msaldopesos",
    "Visa_mlimitecompra", "Visa_madelantopesos", "Visa_mpagado",
    "Visa_mpagospesos", "Visa_mpagominimo"
)

# B. Consumo, Gastos, Costos, Comisiones, Débitos, Cheques Emitidos (GASTO / COSTO)
# USAR Dólar de VENTA (mayor valor)
vars_venta <- c(
    "mcomisiones", "mcomisiones_mantenimiento", "mcomisiones_otras", "mforex_buy",
    "mforex_sell", "mtransferencias_emitidas", "mcheques_emitidos",
    "mcheques_depositados_rechazados", "mcheques_emitidos_rechazados", "matm",
    "matm_other", "mtarjeta_visa_consumo", "mtarjeta_master_consumo",
    "mcuenta_debitos_automaticos", "mpagodeservicios", "mpagomiscuentas",
    "mcajeros_propios_descuentos", "mtarjeta_visa_descuentos", "mtarjeta_master_descuentos",
    "Master_mconsumospesos", "Master_mconsumototal",
    "Visa_mconsumospesos", "Visa_mconsumototal"
)

# Mergear el tipo de cambio al dataset
# Esto adjunta las columnas 'dolar_compra' y 'dolar_venta' según el mes
dataset <- merge(dataset, FACTORES_DOLAR, by = "foto_mes", all.x = TRUE)

# Función de Dolarización (Aplicación In-Place)
dolarizar_vars <- function(dt, vars_list, tipo_cambio_col) {
    # Evitar divisiones por cero (aunque poco probable con tasas reales)
    dt[, tasa := get(tipo_cambio_col) + 1e-9]

    for (v in vars_list) {
        # Asegurar que la columna es numérica (necesario si hay NA o tipos mixtos)
        dt[, (v) := as.numeric(get(v))]

        # Reemplazo in-place: valor_en_pesos / tasa_de_cambio
        dt[, (v) := get(v) / tasa]
    }
    dt[, tasa := NULL] # Limpiar columna temporal
}

# Aplicar la conversión

# Aplicar Dólar de Compra
dolarizar_vars(dataset, vars_compra, "dolar_compra")

# Aplicar Dólar de Venta
dolarizar_vars(dataset, vars_venta, "dolar_venta")

# Limpieza final: Eliminar columnas de tipo de cambio
dataset[, `:=`(dolar_compra = NULL, dolar_venta = NULL)]

cat("Conversión a dólares completada para", length(vars_compra) + length(vars_venta), "variables monetarias.\n")
# Out:
# Conversión a dólares completada para 59 variables monetarias.

# %% [markdown]
# Corrijo el efecto del aguinaldo en 202106 por un factor, en algunas variables

# %%
library(data.table)

# --- Configuración ---
vars_aguinaldo_individual <- c(
    "mcuentas_saldo",
    "mpayroll",
    "mpayroll2",
    "mcaja_ahorro",
    "mcuenta_corriente",
    "mtarjeta_visa_consumo",
    "Visa_mconsumospesos"
)
UMBRAL_AUMENTO <- 1.5      # 50% de aumento (Valor Actual / Media Histórica > 1.5)
FACTOR_CORRECCION <- 1.5   # Factor por el que dividir el valor de 202106 si excede el umbral

#  Asegurar ordenamiento
setorder(dataset, numero_de_cliente, foto_mes)

# Calcular la media histórica (Acumulada) hasta el mes anterior para cada cliente
# Usaremos una media móvil/acumulada (f_prom_cum) para obtener una base robusta.

f_prom_cum <- function(x) {
  # Calcula el promedio acumulado, excluyendo el mes actual (histórico)
  acum_sum <- cumsum(replace(x, is.na(x), 0))
  acum_count <- seq_along(x)

  # Para el mes 'i', la media histórica es: Suma(1 a i-1) / Count(1 a i-1)
  # Creamos una columna temporal de media histórica (rolling mean)
  prom_historico <- shift(acum_sum, 1, NA, "lag") / shift(acum_count, 1, NA, "lag")

  # Manejo de NA para los primeros meses (donde no hay historial)
  prom_historico[is.na(prom_historico)] <- 0 # O se puede dejar en NA, pero 0 es más seguro para la división

  return(prom_historico)
}

# Aplicar el cálculo de la media histórica (temporal) para la detección
for (v in vars_aguinaldo_individual) {
    col_mean_hist <- paste0("mean_hist_", v)
    dataset[, (col_mean_hist) := f_prom_cum(get(v)), by = numero_de_cliente]
}

# %%
# Inicializar el marcador de corrección para impresión
dataset[, fue_corregido := FALSE]

for (v in vars_aguinaldo_individual) {
    col_mean_hist <- paste0("mean_hist_", v)

    # Definir la condición de corrección

    # Condición: foto_mes es 202106 Y (Valor Actual / Media Histórica) > UMBRAL_AUMENTO
    condicion_correccion_v <- dataset$foto_mes == 202106 &
                              !is.na(dataset[[col_mean_hist]]) &
                              dataset[[col_mean_hist]] != 0 &
                              (dataset[[v]] / dataset[[col_mean_hist]]) > UMBRAL_AUMENTO

    # Aplicar la corrección IN-PLACE
    # IMPORTANTE: Reemplazamos la columna original (v) con el valor corregido.
    # Usamos as.numeric() para asegurar que el resultado de la división se almacene correctamente
    dataset[condicion_correccion_v,
            (v) := as.numeric(get(v) / FACTOR_CORRECCION)]

    # Marcar las filas que cumplen la condición
    dataset[condicion_correccion_v, fue_corregido := TRUE]
}

# Limpieza: Eliminar las medias históricas temporales
cols_medias_temp <- paste0("mean_hist_", vars_aguinaldo_individual)
dataset[, (cols_medias_temp) := NULL]

# %%
# Imprimir los clientes y variables corregidas
cols_a_mostrar <- c("numero_de_cliente", "foto_mes", vars_aguinaldo_individual)

tabla_corregida_final <- dataset[foto_mes == 202106 & fue_corregido == TRUE,
                                 .SD,
                                 .SDcols = cols_a_mostrar]

 Limpieza final del indicador
dataset[, fue_corregido := NULL]


if (nrow(tabla_corregida_final) > 0) {
    cat(paste0("Se corrigieron ", nrow(tabla_corregida_final),
               " clientes en 202106 debido a una variación > 50% respecto a su media histórica (01-05).\n"))
    cat("\nPrimeros clientes corregidos con sus valores finales (corregidos):\n")
    print(head(tabla_corregida_final))

    # Nota: Los valores mostrados en esta tabla son los VALORES FINALES ya corregidos
    # (reemplazados in-place en el dataset).
} else {
    cat("No se encontró ningún cliente en 202106 cuya variación superara el 50% en las variables de aguinaldo respecto a su media histórica.\n")
}
# Out:
# Se corrigieron 115915 clientes en 202106 debido a una variación > 50% respecto a su media histórica (01-05).
#
# Primeros clientes corregidos con sus valores finales (corregidos):
#    numero_de_cliente foto_mes mcuentas_saldo mpayroll mpayroll2 mcaja_ahorro
#                <int>    <int>          <num>    <num>     <num>        <num>
# 1:         249221323   202106       93.56882 1218.770         0     119.1303
# 2:         249234235   202106     -163.41262    0.000         0       0.0000
# 3:         249244449   202106     2583.62313    0.000         0    2140.8833
# 4:         249255456   202106    12748.12297 3148.429         0    3838.0639
# 5:         249255747   202106     1387.91115 3785.864         0    1367.0571
# 6:         249257429   202106      617.88947    0.000         0     717.2620
#    mcuenta_corriente mtarjeta_visa_consumo Visa_mconsumospesos
#                <num>                 <num>               <num>
# 1:         -7.380168              262.3166            106.9488
# 2:       -132.677436              107.6859            102.3416
# 3:          0.000000              278.2870            258.9092
# 4:          0.000000              737.8258            633.3316
# 5:          0.000000             1127.2050            902.1273
# 6:          0.000000             1196.6258           1083.8122

# %% [markdown]
# INGENIERÍA DE ATRIBUTOS

# %%
# Lista de variables de saldo líquido a sumar (asumiendo que ya están en USD)
vars_saldos_liquidos <- c(
    "mcuenta_corriente_adicional",
    "mcuenta_corriente",
    "mcaja_ahorro",
    "mcaja_ahorro_adicional"
)

# Creamos la nueva variable mCuentas_Total como la suma de los saldos líquidos
dataset[, mCuentas_Total := rowSums(.SD, na.rm = TRUE), .SDcols = vars_saldos_liquidos]

cat("Variable mCuentas_Total creada con la suma de los saldos líquidos.\n")
# Out:
# Variable mCuentas_Total creada con la suma de los saldos líquidos.

# %%
library(data.table)

# Lista de variables que componen el patrimonio (todos en USD)
vars_patrimonio <- c(
    "mCuentas_Total",           # Ya incluye caja de ahorro y cuenta corriente dolarizadas
    "mplazo_fijo_dolares",      # Ya está en USD
    "mplazo_fijo_pesos",        # Dolarizada
    "minversion1_dolares",      # Ya está en USD
    "minversion1_pesos",        # Dolarizada
    "minversion2"               # Dolarizada (asumiendo que era en pesos)
)

# Creamos la nueva variable mPatrimonio_Total
# Usamos rowSums con na.rm=TRUE para que los NAs (clientes sin esa inversión) se traten como 0.
dataset[, mPatrimonio_Total := rowSums(.SD, na.rm = TRUE), .SDcols = vars_patrimonio]

cat("Variable mPatrimonio_Total creada exitosamente.\n")
# Out:
# Variable mPatrimonio_Total creada exitosamente.

# %% [markdown]
# Lags y Delta Lags

# %%
library(data.table)

# Asegurar que el dataset sea un data.table
if (!is.data.table(dataset)) {
  dataset <- as.data.table(dataset)
}

## Preparación y Ordenamiento

# Columnas a excluir de la generación de lags
cols_excluir <- c("numero_de_cliente", "foto_mes", "clase_ternaria")

# Identificar las columnas a las que se les aplicará el lag
cols_lag <- setdiff(names(dataset), cols_excluir)

# Asegurar el orden temporal para que shift funcione correctamente dentro de cada cliente
setorder(dataset, numero_de_cliente, foto_mes)

## Cálculo de Lag_1 y Delta_lag_1 (Manteniendo tu código original)

# Aplico lag de 1 mes (lag_1)
dataset[, paste0("lag_1_", cols_lag) := lapply(.SD, shift, 1, NA, "lag"),
        by = numero_de_cliente, .SDcols = cols_lag]

# Cálculo de Delta_lag_1 (Actual - Lag_1)
for (v in cols_lag) {
  dataset[, paste0("Delta_lag_1_", v) := get(v) - get(paste0("lag_1_", v))]
}

## Cálculo de Lag_2 y Delta_lag_2 (Nuevas variables)

# Aplico lag de 2 meses (lag_2)
# Usamos n=2 en la función shift
dataset[, paste0("lag_2_", cols_lag) := lapply(.SD, shift, 2, NA, "lag"),
        by = numero_de_cliente, .SDcols = cols_lag]

# Cálculo de Delta_lag_2 (Actual - Lag_2)
# NOTA: Esto captura la diferencia del valor actual respecto a hace dos meses.
for (v in cols_lag) {
  dataset[, paste0("Delta_lag_2_", v) := get(v) - get(paste0("lag_2_", v))]
}

for (v in cols_lag) {
  dataset[, paste0("Delta_lag_1_lag_2_", v) := get(paste0("lag_1_", v)) - get(paste0("lag_2_", v))]
}

# %%
nrow(dataset)
ncol(dataset)
# Out:
# [1] 978439
# [1] 927

# %% [markdown]
# Pendiente

# %%
# Función de Pendiente con Ventana Fija (W)
# W es la ventana de meses a considerar (ej. 3 meses)
f_pendiente_ventana <- function(x, W = 3) {
  # Función para calcular la pendiente de una serie temporal corta
  calc_pend <- function(ventana) {
    ventana <- ventana[!is.na(ventana)]
    if (length(ventana) < 2) return(NA_real_)
    t <- 1:length(ventana)
    # Usa 'coef' para extraer el coeficiente de la variable 't' (el tiempo)
    return(coef(lm(ventana ~ t))[2])
  }

  # Aplica una ventana móvil (rollapply)
  # En data.table, se simula con 'frollapply' si está disponible (versión > 1.13) o un loop

  # Usando frollapply de data.table (rápido para ventanas fijas)
  # Si tu versión de data.table lo soporta:
  if (exists("frollapply")) {
    return(frollapply(x, W, calc_pend, align = "right", fill = NA_real_))
  } else {
    # Alternativa manual para versiones antiguas
    pendientes <- rep(NA_real_, length(x))
    for (i in W:length(x)) {
      pendientes[i] <- calc_pend(x[(i - W + 1):i])
    }
    return(pendientes)
  }
}

# Aplicación:
pend_vars_ventana <- c("ctrx_quarter", "cproductos")
for (v in pend_vars_ventana) {
  newcol <- paste0("pend_3m_", v)
  # W=3 para los últimos 3 meses
  dataset[, (newcol) := f_pendiente_ventana(get(v), W = 3), by = numero_de_cliente]
}

# %%
nrow(dataset)
ncol(dataset)
# Out:
# [1] 978439
# [1] 929

# %% [markdown]
# Ranking, promedio y rangos (max-min)

# %%
library(data.table)
library(stats)  # Para asegurar que ecdf esté disponible

# Funciones Acumuladas (Vectorizadas/Semi-Vectorizadas)

# Rango Acumulado (Vectorizado)
f_rango_cum <- function(x) {
  # Asegura que el NA no se propague inmediatamente si el primer valor es NA
  x_no_na <- replace(x, is.na(x), x[1]) # Reemplazo temporal para que cummin/max funcione
  cummax(x) - cummin(x)
}

# Promedio Acumulado (Vectorizado) - Correcto, maneja NAs reemplazándolos con 0 en la suma
f_prom_cum <- function(x) {
  cumsum(replace(x, is.na(x), 0)) / seq_along(x)
}


f_ranking <- function(x) {
  ranks <- rep(NA_real_, length(x))

  for (i in seq_along(x)) {
    val <- x[i]

    if (is.na(val)) next

    # Historial de valores ANTERIORES al mes actual
    historial <- if (i > 1) x[1:(i - 1)] else numeric(0)
    historial <- historial[!is.na(historial)] # Remover NAs del historial

    # Si no hay historial, se inicializa a 0.5 (neutral)
    if (length(historial) == 0) {
      ranks[i] <- 0.5
      next
    }

    # --- Lógica de Ranking con Cero Fijo ---
    if (val == 0) {
      ranks[i] <- 0 # El valor 0 debe ser el punto central/neutro (0)
    } else if (val > 0) {
      # 1. POSITIVOS (Rango [0, 1])
      historial_pos <- historial[historial > 0]
      if (length(historial_pos) > 0) {
        # El ECDF ya da un ranking de 0 a 1.
        ranks[i] <- ecdf(historial_pos)(val)
      } else {
        # Si no hay historial positivo, es el más alto (1)
        ranks[i] <- 1
      }
    } else { # val < 0
      # 2. NEGATIVOS (Rango [-1, 0])
      historial_neg <- historial[historial < 0]

      if (length(historial_neg) > 0) {
        # Para obtener un ranking de 0 a -1, aplicamos ECDF sobre
        # los valores NEGATIVOS de -historial (transformados a positivos)
        # y luego multiplicamos el resultado por -1.

        # El ECDF se aplica al valor -val (que es positivo) dentro de
        # la distribución de -historial_neg. Esto da 1 para los valores
        # más cercanos a cero (los menos negativos) y 0 para los más lejanos.
        # Multiplicar por -1 invierte el orden y el signo:
        # Rank 1 -> -1, Rank 0 -> 0.
        ranks[i] <- -ecdf(-historial_neg)(-val)

      } else {
        # Si no hay historial negativo, es el más bajo (-1)
        ranks[i] <- -1
      }
    }
  }
  return(ranks)
}


# Aplicación de Features al dataset COMPLETO


# RANGOS (vectorizado)
rango_vars <- c("mcuentas_saldo", "Master_msaldototal", "Visa_msaldototal")
for (v in rango_vars) {
  newcol <- paste0("rango_acum_", v)
  # Aplicación directa sobre el dataset completo
  dataset[, (newcol) := f_rango_cum(get(v)), by = numero_de_cliente]
}

# PROMEDIOS (vectorizado)
prom_vars <- c("mpasivos_margen", "cproductos",
               "Master_mlimitecompra", "Visa_mlimitecompra",
               "ctarjeta_visa", "ctarjeta_master", "ctrx_quarter")
for (v in prom_vars) {
  newcol <- paste0("prom_acum_", v)
  # Aplicación directa sobre el dataset completo
  dataset[, (newcol) := f_prom_cum(get(v)), by = numero_de_cliente]
}

# RANKINGS (requiere función incremental)
rank_vars <- c("mtarjeta_visa_consumo", "mtarjeta_master_consumo",
               "Master_mconsumototal", "Visa_mconsumototal",
               "Master_cconsumos", "Visa_cconsumos", "ctrx_quarter",
               "cpayroll_trx","mpayroll","cliente_edad")

dataset[, (rank_vars) := lapply(.SD, as.numeric), .SDcols = rank_vars]

for (v in rank_vars) {
  # newcol <- paste0("rank_acum_", v)
  # Aplicación directa sobre el dataset completo
  dataset[, (v) := f_ranking(get(v)), by = numero_de_cliente]
}

# %%
nrow(dataset)
ncol(dataset)
# Out:
# [1] 978439
# [1] 939

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in%  PARAM$train &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 53249
# [1] 938

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sat Oct 11 12:19:59 2025 AUC 0.924349689933132
#
# Sat Oct 11 12:21:24 2025 AUC 0.920671520388602
#
# Sat Oct 11 12:23:50 2025 AUC 0.926772310162526
#
# Sat Oct 11 12:27:01 2025 AUC 0.922573211779931
#
# Sat Oct 11 12:28:29 2025 AUC 0.927740301908169
#
# Sat Oct 11 12:31:01 2025 AUC 0.925818354950716
#
# Sat Oct 11 12:32:00 2025 AUC 0.921110241165373
#
# Sat Oct 11 12:32:28 2025 AUC 0.919331050457514
#
# Sat Oct 11 12:34:20 2025 AUC 0.925737365664357
#
# Sat Oct 11 12:36:14 2025 AUC 0.920124144668092
#
# Sat Oct 11 12:37:04 2025 AUC 0.923874868795407
#
# Sat Oct 11 12:39:11 2025 AUC 0.922274268469908
#
# Sat Oct 11 12:40:26 2025 AUC 0.92576233511168
#
# Sat Oct 11 12:42:52 2025 AUC 0.924306445824256
#
# Sat Oct 11 12:44:10 2025 AUC 0.917302257967317
#
# Sat Oct 11 12:44:40 2025 AUC 0.921402426038639
#
# Sat Oct 11 12:48:56 2025 AUC 0.925953363230855
#
# Sat Oct 11 12:49:38 2025 AUC 0.920447640924821
#
# Sat Oct 11 12:53:46 2025 AUC 0.925676658446226
#
# Sat Oct 11 12:57:28 2025 AUC 0.927310160087474
#
# Sat Oct 11 12:57:35 2025 AUC 0.859615566741238
#
# Sat Oct 11 12:58:47 2025 AUC 0.923391464337984
#
# Sat Oct 11 12:59:53 2025 AUC 0.919645115152753
#
# Sat Oct 11 13:00:22 2025 AUC 0.893381519630432
#
# Sat Oct 11 13:03:12 2025 AUC 0.930392372354117
#
# Sat Oct 11 13:05:09 2025 AUC 0.927681617460319
#
# Sat Oct 11 13:05:40 2025 AUC 0.923890690989777
#
# Sat Oct 11 13:08:36 2025 AUC 0.912330517530142
#
# Sat Oct 11 13:12:14 2025 AUC 0.925382647796735
#
# Sat Oct 11 13:14:33 2025 AUC 0.926430353472558
#
# Sat Oct 11 13:14:55 2025 AUC 0.906342652739907
#
# Sat Oct 11 13:15:16 2025 AUC 0.919702630070238
#
# Sat Oct 11 13:18:24 2025 AUC 0.925238739380447
#
# Sat Oct 11 13:19:56 2025 AUC 0.921715846063685
#
# Sat Oct 11 13:22:35 2025 AUC 0.919259039563057
#
# Sat Oct 11 13:24:19 2025 AUC 0.92553777757726
#
# Sat Oct 11 13:26:09 2025 AUC 0.924154528946352
#
# Sat Oct 11 13:27:26 2025 AUC 0.924202016449526
#
# Sat Oct 11 13:28:10 2025 AUC 0.915171464314095
#
# Sat Oct 11 13:29:39 2025 AUC 0.917734480917929
#
# Sat Oct 11 13:30:48 2025 AUC 0.92144047603033
#
# Sat Oct 11 13:31:32 2025 AUC 0.912565300407677
#
# Sat Oct 11 13:36:15 2025 AUC 0.930868219087631
#
# Sat Oct 11 13:37:20 2025 AUC 0.914740017533578
#
# Sat Oct 11 13:39:30 2025 AUC 0.931597433490274
#
# Sat Oct 11 13:42:02 2025 AUC 0.921213342288586
#
# Sat Oct 11 13:43:37 2025 AUC 0.924870297659519
#
# Sat Oct 11 13:44:55 2025 AUC 0.920391493950635
#
# Sat Oct 11 13:45:38 2025 AUC 0.905186055719101
#
# Sat Oct 11 13:46:35 2025 AUC 0.921471314889728
#
# Sat Oct 11 13:48:58 2025 AUC 0.920478261748757
#
# Sat Oct 11 13:50:12 2025 AUC 0.926210251531951
#
# [mbo] 0: num_iterations=391; learning_rate=0.0393; feature_fraction=0.644; num_leaves=94; min_data_in_leaf=1906; lambda_l1=3.37; lambda_l2=3.28; bagging_fraction=0.822; bagging_freq=4; min_gain_to_split=3.62; min_sum_hessian_in_leaf=2.5; max_depth=10; max_bin=464 : y = 0.924 : 55.9 secs : initdesign
#
# [mbo] 0: num_iterations=1057; learning_rate=0.0268; feature_fraction=0.665; num_leaves=150; min_data_in_leaf=2540; lambda_l1=1.85; lambda_l2=3.83; bagging_fraction=0.649; bagging_freq=1; min_gain_to_split=6.74; min_sum_hessian_in_leaf=6.58; max_depth=3; max_bin=412 : y = 0.921 : 84.4 secs : initdesign
#
# [mbo] 0: num_iterations=1640; learning_rate=0.0415; feature_fraction=0.725; num_leaves=212; min_data_in_leaf=904; lambda_l1=3.61; lambda_l2=5.75; bagging_fraction=0.857; bagging_freq=2; min_gain_to_split=3.12; min_sum_hessian_in_leaf=4.6; max_depth=8; max_bin=472 : y = 0.927 : 146.7 secs : initdesign
#
# [mbo] 0: num_iterations=1385; learning_rate=0.0324; feature_fraction=0.564; num_leaves=165; min_data_in_leaf=1198; lambda_l1=3.68; lambda_l2=6.6; bagging_fraction=0.674; bagging_freq=4; min_gain_to_split=6.33; min_sum_hessian_in_leaf=3.76; max_depth=4; max_bin=448 : y = 0.923 : 190.5 secs : initdesign
#
# [mbo] 0: num_iterations=1239; learning_rate=0.045; feature_fraction=0.742; num_leaves=124; min_data_in_leaf=291; lambda_l1=2.07; lambda_l2=1.7; bagging_fraction=0.755; bagging_freq=3; min_gain_to_split=2.58; min_sum_hessian_in_leaf=1.02; max_depth=2; max_bin=324 : y = 0.928 : 87.9 secs : initdesign
#
# [mbo] 0: num_iterations=1904; learning_rate=0.0305; feature_fraction=0.621; num_leaves=41; min_data_in_leaf=597; lambda_l1=2.39; lambda_l2=4.72; bagging_fraction=0.796; bagging_freq=3; min_gain_to_split=5.66; min_sum_hessian_in_leaf=5.03; max_depth=7; max_bin=375 : y = 0.926 : 151.7 secs : initdesign
#
# [mbo] 0: num_iterations=873; learning_rate=0.0335; feature_fraction=0.678; num_leaves=68; min_data_in_leaf=1499; lambda_l1=4.05; lambda_l2=2.99; bagging_fraction=0.597; bagging_freq=2; min_gain_to_split=7.47; min_sum_hessian_in_leaf=6.78; max_depth=7; max_bin=273 : y = 0.921 : 59.7 secs : initdesign
#
# [mbo] 0: num_iterations=164; learning_rate=0.0426; feature_fraction=0.604; num_leaves=33; min_data_in_leaf=1802; lambda_l1=1.12; lambda_l2=5.53; bagging_fraction=0.563; bagging_freq=4; min_gain_to_split=5.16; min_sum_hessian_in_leaf=6.65; max_depth=8; max_bin=391 : y = 0.919 : 27.7 secs : initdesign
#
# [mbo] 0: num_iterations=760; learning_rate=0.0548; feature_fraction=0.55; num_leaves=146; min_data_in_leaf=758; lambda_l1=0.947; lambda_l2=7.34; bagging_fraction=0.782; bagging_freq=2; min_gain_to_split=4.9; min_sum_hessian_in_leaf=2.99; max_depth=11; max_bin=254 : y = 0.926 : 111.9 secs : initdesign
#
# [mbo] 0: num_iterations=828; learning_rate=0.0107; feature_fraction=0.459; num_leaves=70; min_data_in_leaf=1644; lambda_l1=2.92; lambda_l2=4.15; bagging_fraction=0.659; bagging_freq=1; min_gain_to_split=7.72; min_sum_hessian_in_leaf=0.113; max_depth=13; max_bin=165 : y = 0.92 : 114.2 secs : initdesign
#
# [mbo] 0: num_iterations=835; learning_rate=0.0294; feature_fraction=0.718; num_leaves=31; min_data_in_leaf=716; lambda_l1=1.73; lambda_l2=1.79; bagging_fraction=0.839; bagging_freq=1; min_gain_to_split=9.21; min_sum_hessian_in_leaf=4.86; max_depth=9; max_bin=130 : y = 0.924 : 49.5 secs : initdesign
#
# [mbo] 0: num_iterations=1719; learning_rate=0.018; feature_fraction=0.749; num_leaves=183; min_data_in_leaf=2244; lambda_l1=3.25; lambda_l2=3.2; bagging_fraction=0.801; bagging_freq=3; min_gain_to_split=5.53; min_sum_hessian_in_leaf=0.351; max_depth=11; max_bin=291 : y = 0.922 : 127.1 secs : initdesign
#
# [mbo] 0: num_iterations=508; learning_rate=0.0483; feature_fraction=0.598; num_leaves=131; min_data_in_leaf=2346; lambda_l1=2.16; lambda_l2=7.04; bagging_fraction=0.948; bagging_freq=5; min_gain_to_split=0.6; min_sum_hessian_in_leaf=3.98; max_depth=4; max_bin=370 : y = 0.926 : 75.5 secs : initdesign
#
# [mbo] 0: num_iterations=1880; learning_rate=0.0543; feature_fraction=0.769; num_leaves=138; min_data_in_leaf=3007; lambda_l1=2.58; lambda_l2=6.19; bagging_fraction=0.808; bagging_freq=1; min_gain_to_split=4.46; min_sum_hessian_in_leaf=2.75; max_depth=14; max_bin=510 : y = 0.924 : 146.1 secs : initdesign
#
# [mbo] 0: num_iterations=620; learning_rate=0.0517; feature_fraction=0.525; num_leaves=256; min_data_in_leaf=2910; lambda_l1=3.86; lambda_l2=2.28; bagging_fraction=0.636; bagging_freq=4; min_gain_to_split=7.09; min_sum_hessian_in_leaf=5.31; max_depth=15; max_bin=147 : y = 0.917 : 77.5 secs : initdesign
#
# [mbo] 0: num_iterations=345; learning_rate=0.0506; feature_fraction=0.706; num_leaves=84; min_data_in_leaf=2444; lambda_l1=4.83; lambda_l2=8.91; bagging_fraction=0.909; bagging_freq=2; min_gain_to_split=6.01; min_sum_hessian_in_leaf=5.55; max_depth=4; max_bin=173 : y = 0.921 : 30.5 secs : initdesign
#
# [mbo] 0: num_iterations=1580; learning_rate=0.0158; feature_fraction=0.483; num_leaves=76; min_data_in_leaf=2154; lambda_l1=2.3; lambda_l2=8.04; bagging_fraction=0.984; bagging_freq=5; min_gain_to_split=2.36; min_sum_hessian_in_leaf=2.81; max_depth=16; max_bin=359 : y = 0.926 : 255.8 secs : initdesign
#
# [mbo] 0: num_iterations=235; learning_rate=0.0283; feature_fraction=0.588; num_leaves=43; min_data_in_leaf=1007; lambda_l1=1.36; lambda_l2=9.31; bagging_fraction=0.619; bagging_freq=3; min_gain_to_split=8.35; min_sum_hessian_in_leaf=1.12; max_depth=9; max_bin=341 : y = 0.92 : 42.1 secs : initdesign
#
# [mbo] 0: num_iterations=1961; learning_rate=0.0472; feature_fraction=0.488; num_leaves=239; min_data_in_leaf=1881; lambda_l1=2.64; lambda_l2=5.04; bagging_fraction=0.595; bagging_freq=3; min_gain_to_split=3.05; min_sum_hessian_in_leaf=2.16; max_depth=10; max_bin=242 : y = 0.926 : 247.4 secs : initdesign
#
# [mbo] 0: num_iterations=1765; learning_rate=0.0235; feature_fraction=0.681; num_leaves=63; min_data_in_leaf=2004; lambda_l1=2; lambda_l2=1.18; bagging_fraction=0.831; bagging_freq=5; min_gain_to_split=2.21; min_sum_hessian_in_leaf=6.27; max_depth=11; max_bin=385 : y = 0.927 : 222.2 secs : initdesign
#
# [mbo] 0: num_iterations=34; learning_rate=0.028; feature_fraction=0.567; num_leaves=192; min_data_in_leaf=868; lambda_l1=4.21; lambda_l2=2.11; bagging_fraction=0.69; bagging_freq=4; min_gain_to_split=7.95; min_sum_hessian_in_leaf=0.464; max_depth=1; max_bin=101 : y = 0.86 : 7.1 secs : initdesign
#
# [mbo] 0: num_iterations=646; learning_rate=0.0202; feature_fraction=0.699; num_leaves=120; min_data_in_leaf=3064; lambda_l1=3.3; lambda_l2=3.89; bagging_fraction=0.707; bagging_freq=0; min_gain_to_split=2.78; min_sum_hessian_in_leaf=1.9; max_depth=5; max_bin=153 : y = 0.923 : 72.4 secs : initdesign
#
# [mbo] 0: num_iterations=444; learning_rate=0.0146; feature_fraction=0.635; num_leaves=135; min_data_in_leaf=1116; lambda_l1=4.44; lambda_l2=7.66; bagging_fraction=0.557; bagging_freq=2; min_gain_to_split=7.61; min_sum_hessian_in_leaf=5.51; max_depth=-1; max_bin=441 : y = 0.92 : 65.4 secs : initdesign
#
# [mbo] 0: num_iterations=122; learning_rate=0.00722; feature_fraction=0.766; num_leaves=110; min_data_in_leaf=2615; lambda_l1=1.8; lambda_l2=8.78; bagging_fraction=0.933; bagging_freq=4; min_gain_to_split=8.11; min_sum_hessian_in_leaf=2.06; max_depth=15; max_bin=334 : y = 0.893 : 28.9 secs : initdesign
#
# [mbo] 0: num_iterations=1127; learning_rate=0.0352; feature_fraction=0.659; num_leaves=247; min_data_in_leaf=376; lambda_l1=3.08; lambda_l2=3.49; bagging_fraction=0.693; bagging_freq=5; min_gain_to_split=0.0924; min_sum_hessian_in_leaf=7.29; max_depth=4; max_bin=453 : y = 0.93 : 170.3 secs : initdesign
#
# [mbo] 0: num_iterations=1462; learning_rate=0.0431; feature_fraction=0.647; num_leaves=155; min_data_in_leaf=2198; lambda_l1=3.75; lambda_l2=6.82; bagging_fraction=0.873; bagging_freq=4; min_gain_to_split=0.998; min_sum_hessian_in_leaf=1.49; max_depth=0; max_bin=74 : y = 0.928 : 117.0 secs : initdesign
#
# [mbo] 0: num_iterations=265; learning_rate=0.0581; feature_fraction=0.754; num_leaves=189; min_data_in_leaf=2745; lambda_l1=0.974; lambda_l2=0.824; bagging_fraction=0.929; bagging_freq=3; min_gain_to_split=4.04; min_sum_hessian_in_leaf=6.12; max_depth=8; max_bin=176 : y = 0.924 : 31.4 secs : initdesign
#
# [mbo] 0: num_iterations=1346; learning_rate=0.0127; feature_fraction=0.524; num_leaves=167; min_data_in_leaf=1038; lambda_l1=3.52; lambda_l2=2.81; bagging_fraction=0.896; bagging_freq=4; min_gain_to_split=7.3; min_sum_hessian_in_leaf=4.43; max_depth=1; max_bin=489 : y = 0.912 : 176.2 secs : initdesign
#
# [mbo] 0: num_iterations=1660; learning_rate=0.0535; feature_fraction=0.503; num_leaves=13; min_data_in_leaf=2419; lambda_l1=2.77; lambda_l2=8.18; bagging_fraction=0.726; bagging_freq=1; min_gain_to_split=3.75; min_sum_hessian_in_leaf=6.45; max_depth=10; max_bin=222 : y = 0.925 : 217.2 secs : initdesign
#
# [mbo] 0: num_iterations=1532; learning_rate=0.0402; feature_fraction=0.732; num_leaves=178; min_data_in_leaf=664; lambda_l1=0.852; lambda_l2=5.3; bagging_fraction=0.571; bagging_freq=0; min_gain_to_split=4.39; min_sum_hessian_in_leaf=4.27; max_depth=-1; max_bin=481 : y = 0.926 : 139.4 secs : initdesign
#
# [mbo] 0: num_iterations=196; learning_rate=0.0139; feature_fraction=0.628; num_leaves=221; min_data_in_leaf=2088; lambda_l1=3.01; lambda_l2=2.42; bagging_fraction=0.511; bagging_freq=1; min_gain_to_split=9.47; min_sum_hessian_in_leaf=0.645; max_depth=13; max_bin=432 : y = 0.906 : 22.2 secs : initdesign
#
# [mbo] 0: num_iterations=71; learning_rate=0.0382; feature_fraction=0.616; num_leaves=48; min_data_in_leaf=108; lambda_l1=0.738; lambda_l2=9.9; bagging_fraction=0.772; bagging_freq=0; min_gain_to_split=4; min_sum_hessian_in_leaf=7.11; max_depth=6; max_bin=296 : y = 0.92 : 21.1 secs : initdesign
#
# [mbo] 0: num_iterations=996; learning_rate=0.0344; feature_fraction=0.574; num_leaves=215; min_data_in_leaf=3212; lambda_l1=1.26; lambda_l2=5.95; bagging_fraction=0.994; bagging_freq=0; min_gain_to_split=0.326; min_sum_hessian_in_leaf=5.93; max_depth=3; max_bin=496 : y = 0.925 : 187.8 secs : initdesign
#
# [mbo] 0: num_iterations=1164; learning_rate=0.019; feature_fraction=0.781; num_leaves=25; min_data_in_leaf=3367; lambda_l1=0.0284; lambda_l2=9.11; bagging_fraction=0.579; bagging_freq=2; min_gain_to_split=0.818; min_sum_hessian_in_leaf=3.2; max_depth=6; max_bin=120 : y = 0.922 : 91.3 secs : initdesign
#
# [mbo] 0: num_iterations=983; learning_rate=0.0254; feature_fraction=0.535; num_leaves=101; min_data_in_leaf=2888; lambda_l1=3.96; lambda_l2=0.711; bagging_fraction=0.958; bagging_freq=2; min_gain_to_split=9.01; min_sum_hessian_in_leaf=2.37; max_depth=14; max_bin=211 : y = 0.919 : 159.9 secs : initdesign
#
# [mbo] 0: num_iterations=684; learning_rate=0.0248; feature_fraction=0.468; num_leaves=161; min_data_in_leaf=1588; lambda_l1=4.27; lambda_l2=9.55; bagging_fraction=0.631; bagging_freq=1; min_gain_to_split=1.6; min_sum_hessian_in_leaf=0.784; max_depth=12; max_bin=232 : y = 0.926 : 103.9 secs : initdesign
#
# [mbo] 0: num_iterations=1798; learning_rate=0.00923; feature_fraction=0.606; num_leaves=175; min_data_in_leaf=512; lambda_l1=4.94; lambda_l2=8.58; bagging_fraction=0.612; bagging_freq=1; min_gain_to_split=6.57; min_sum_hessian_in_leaf=7.01; max_depth=12; max_bin=111 : y = 0.924 : 109.4 secs : initdesign
#
# [mbo] 0: num_iterations=1837; learning_rate=0.049; feature_fraction=0.737; num_leaves=22; min_data_in_leaf=1325; lambda_l1=0.416; lambda_l2=1.16; bagging_fraction=0.521; bagging_freq=4; min_gain_to_split=5.33; min_sum_hessian_in_leaf=3.33; max_depth=7; max_bin=318 : y = 0.924 : 76.9 secs : initdesign
#
# [mbo] 0: num_iterations=1197; learning_rate=0.0498; feature_fraction=0.653; num_leaves=195; min_data_in_leaf=3142; lambda_l1=0.529; lambda_l2=7.14; bagging_fraction=0.537; bagging_freq=3; min_gain_to_split=8.75; min_sum_hessian_in_leaf=4.05; max_depth=15; max_bin=262 : y = 0.915 : 44.0 secs : initdesign
#
# [mbo] 0: num_iterations=1310; learning_rate=0.00573; feature_fraction=0.691; num_leaves=106; min_data_in_leaf=2790; lambda_l1=1.62; lambda_l2=4.53; bagging_fraction=0.98; bagging_freq=2; min_gain_to_split=4.71; min_sum_hessian_in_leaf=7.82; max_depth=3; max_bin=184 : y = 0.918 : 89.1 secs : initdesign
#
# [mbo] 0: num_iterations=577; learning_rate=0.0594; feature_fraction=0.496; num_leaves=91; min_data_in_leaf=1403; lambda_l1=1.24; lambda_l2=6.05; bagging_fraction=0.915; bagging_freq=5; min_gain_to_split=9.33; min_sum_hessian_in_leaf=5.19; max_depth=5; max_bin=205 : y = 0.921 : 69.1 secs : initdesign
#
# [mbo] 0: num_iterations=1264; learning_rate=0.0219; feature_fraction=0.789; num_leaves=115; min_data_in_leaf=3435; lambda_l1=4.59; lambda_l2=6.48; bagging_fraction=0.546; bagging_freq=5; min_gain_to_split=8.52; min_sum_hessian_in_leaf=3.49; max_depth=2; max_bin=195 : y = 0.913 : 43.9 secs : initdesign
#
# [mbo] 0: num_iterations=2003; learning_rate=0.0221; feature_fraction=0.472; num_leaves=85; min_data_in_leaf=472; lambda_l1=4.79; lambda_l2=0.476; bagging_fraction=0.887; bagging_freq=3; min_gain_to_split=1.41; min_sum_hessian_in_leaf=7.44; max_depth=13; max_bin=244 : y = 0.931 : 283.6 secs : initdesign
#
# [mbo] 0: num_iterations=532; learning_rate=0.0367; feature_fraction=0.515; num_leaves=233; min_data_in_leaf=159; lambda_l1=1.46; lambda_l2=0.312; bagging_fraction=0.747; bagging_freq=0; min_gain_to_split=0.538; min_sum_hessian_in_leaf=7.67; max_depth=1; max_bin=406 : y = 0.915 : 64.4 secs : initdesign
#
# [mbo] 0: num_iterations=910; learning_rate=0.056; feature_fraction=0.555; num_leaves=248; min_data_in_leaf=231; lambda_l1=0.305; lambda_l2=8.44; bagging_fraction=0.667; bagging_freq=1; min_gain_to_split=1.75; min_sum_hessian_in_leaf=0.157; max_depth=0; max_bin=134 : y = 0.932 : 130.6 secs : initdesign
#
# [mbo] 0: num_iterations=1558; learning_rate=0.00927; feature_fraction=0.507; num_leaves=12; min_data_in_leaf=1445; lambda_l1=2.87; lambda_l2=4.34; bagging_fraction=0.501; bagging_freq=5; min_gain_to_split=6.43; min_sum_hessian_in_leaf=1.69; max_depth=16; max_bin=66 : y = 0.921 : 152.0 secs : initdesign
#
# [mbo] 0: num_iterations=1424; learning_rate=0.0115; feature_fraction=0.779; num_leaves=201; min_data_in_leaf=51; lambda_l1=0.204; lambda_l2=7.85; bagging_fraction=0.737; bagging_freq=5; min_gain_to_split=9.65; min_sum_hessian_in_leaf=4.63; max_depth=5; max_bin=308 : y = 0.925 : 95.0 secs : initdesign
#
# [mbo] 0: num_iterations=2026; learning_rate=0.0571; feature_fraction=0.71; num_leaves=228; min_data_in_leaf=3248; lambda_l1=4.63; lambda_l2=9.78; bagging_fraction=0.855; bagging_freq=0; min_gain_to_split=5.91; min_sum_hessian_in_leaf=7.89; max_depth=9; max_bin=88 : y = 0.92 : 77.5 secs : initdesign
#
# [mbo] 0: num_iterations=317; learning_rate=0.0062; feature_fraction=0.579; num_leaves=224; min_data_in_leaf=2636; lambda_l1=0.592; lambda_l2=0.111; bagging_fraction=0.97; bagging_freq=0; min_gain_to_split=2.07; min_sum_hessian_in_leaf=5.83; max_depth=16; max_bin=89 : y = 0.905 : 42.7 secs : initdesign
#
# [mbo] 0: num_iterations=419; learning_rate=0.0456; feature_fraction=0.452; num_leaves=206; min_data_in_leaf=3361; lambda_l1=2.46; lambda_l2=1.36; bagging_fraction=0.717; bagging_freq=5; min_gain_to_split=1.26; min_sum_hessian_in_leaf=1.25; max_depth=0; max_bin=352 : y = 0.921 : 57.6 secs : initdesign
#
# [mbo] 0: num_iterations=1095; learning_rate=0.0168; feature_fraction=0.54; num_leaves=56; min_data_in_leaf=1714; lambda_l1=0.175; lambda_l2=2.67; bagging_fraction=0.878; bagging_freq=0; min_gain_to_split=9.84; min_sum_hessian_in_leaf=1.7; max_depth=-1; max_bin=285 : y = 0.92 : 143.1 secs : initdesign
#
# [mbo] 0: num_iterations=739; learning_rate=0.0369; feature_fraction=0.794; num_leaves=53; min_data_in_leaf=1243; lambda_l1=4.36; lambda_l2=4.84; bagging_fraction=0.765; bagging_freq=2; min_gain_to_split=3.29; min_sum_hessian_in_leaf=3.59; max_depth=12; max_bin=417 : y = 0.926 : 73.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Sat Oct 11 13:56:38 2025 AUC 0.934194085658238
#
# [mbo] 1: num_iterations=1420; learning_rate=0.0363; feature_fraction=0.694; num_leaves=165; min_data_in_leaf=24; lambda_l1=0.885; lambda_l2=9.85; bagging_fraction=0.666; bagging_freq=1; min_gain_to_split=0.0493; min_sum_hessian_in_leaf=2.95; max_depth=8; max_bin=199 : y = 0.934 : 378.9 secs : infill_ei
#
# Sat Oct 11 13:58:15 2025 AUC 0.92799608776199
#
# [mbo] 2: num_iterations=1609; learning_rate=0.0428; feature_fraction=0.758; num_leaves=198; min_data_in_leaf=625; lambda_l1=0.513; lambda_l2=9.41; bagging_fraction=0.665; bagging_freq=2; min_gain_to_split=0.998; min_sum_hessian_in_leaf=1.59; max_depth=3; max_bin=237 : y = 0.928 : 96.1 secs : infill_ei
#
# Sat Oct 11 14:01:16 2025 AUC 0.932076609631904
#
# [mbo] 3: num_iterations=1040; learning_rate=0.0378; feature_fraction=0.718; num_leaves=144; min_data_in_leaf=190; lambda_l1=0.676; lambda_l2=8.82; bagging_fraction=0.663; bagging_freq=1; min_gain_to_split=1.02; min_sum_hessian_in_leaf=3.44; max_depth=7; max_bin=313 : y = 0.932 : 179.8 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Sat Oct 11 14:04:04 2025 AUC 0.929035910782222
#
# [mbo] 4: num_iterations=1219; learning_rate=0.0362; feature_fraction=0.571; num_leaves=20; min_data_in_leaf=290; lambda_l1=1.67; lambda_l2=9.48; bagging_fraction=0.874; bagging_freq=0; min_gain_to_split=1.8; min_sum_hessian_in_leaf=2.47; max_depth=8; max_bin=153 : y = 0.929 : 161.1 secs : infill_ei
#
# Sat Oct 11 14:06:30 2025 AUC 0.929314901651304
#
# [mbo] 5: num_iterations=1209; learning_rate=0.0598; feature_fraction=0.635; num_leaves=76; min_data_in_leaf=2535; lambda_l1=3.72; lambda_l2=1.41; bagging_fraction=0.917; bagging_freq=2; min_gain_to_split=0.105; min_sum_hessian_in_leaf=1.14; max_depth=13; max_bin=267 : y = 0.929 : 145.7 secs : infill_ei
#
# Sat Oct 11 14:09:56 2025 AUC 0.930007686786886
#
# [mbo] 6: num_iterations=1640; learning_rate=0.0203; feature_fraction=0.623; num_leaves=97; min_data_in_leaf=1298; lambda_l1=4.44; lambda_l2=6.54; bagging_fraction=0.74; bagging_freq=0; min_gain_to_split=0.512; min_sum_hessian_in_leaf=5.2; max_depth=9; max_bin=251 : y = 0.93 : 205.0 secs : infill_ei
#
# Sat Oct 11 14:13:58 2025 AUC 0.930635050325139
#
# [mbo] 7: num_iterations=1418; learning_rate=0.0182; feature_fraction=0.471; num_leaves=103; min_data_in_leaf=13; lambda_l1=2.71; lambda_l2=7.52; bagging_fraction=0.513; bagging_freq=2; min_gain_to_split=2.44; min_sum_hessian_in_leaf=1.5; max_depth=9; max_bin=449 : y = 0.931 : 240.6 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Sat Oct 11 14:21:16 2025 AUC 0.932147722109613
#
# [mbo] 8: num_iterations=1456; learning_rate=0.0371; feature_fraction=0.712; num_leaves=163; min_data_in_leaf=190; lambda_l1=3.1; lambda_l2=8.11; bagging_fraction=0.643; bagging_freq=4; min_gain_to_split=0.00477; min_sum_hessian_in_leaf=6.05; max_depth=9; max_bin=313 : y = 0.932 : 431.3 secs : infill_ei
#
# Sat Oct 11 14:23:59 2025 AUC 0.925229445827542
#
# [mbo] 9: num_iterations=1046; learning_rate=0.0589; feature_fraction=0.536; num_leaves=252; min_data_in_leaf=2679; lambda_l1=3.03; lambda_l2=3.8; bagging_fraction=0.639; bagging_freq=5; min_gain_to_split=0.0181; min_sum_hessian_in_leaf=3.05; max_depth=8; max_bin=455 : y = 0.925 : 162.1 secs : infill_ei
#
# Sat Oct 11 14:29:44 2025 AUC 0.93017916584464
#
# [mbo] 10: num_iterations=1815; learning_rate=0.0337; feature_fraction=0.664; num_leaves=108; min_data_in_leaf=1020; lambda_l1=3.1; lambda_l2=7.68; bagging_fraction=0.647; bagging_freq=1; min_gain_to_split=0.0514; min_sum_hessian_in_leaf=3.09; max_depth=0; max_bin=473 : y = 0.93 : 344.0 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Sat Oct 11 14:31:24 2025 AUC 0.925792194938632
#
# [mbo] 11: num_iterations=619; learning_rate=0.0451; feature_fraction=0.476; num_leaves=62; min_data_in_leaf=3384; lambda_l1=2.59; lambda_l2=4.3; bagging_fraction=0.73; bagging_freq=0; min_gain_to_split=1.41; min_sum_hessian_in_leaf=0.312; max_depth=8; max_bin=405 : y = 0.926 : 95.4 secs : infill_ei
#
# Sat Oct 11 14:36:13 2025 AUC 0.933383047716763
#
# [mbo] 12: num_iterations=1266; learning_rate=0.0547; feature_fraction=0.713; num_leaves=121; min_data_in_leaf=113; lambda_l1=2.62; lambda_l2=5.57; bagging_fraction=0.673; bagging_freq=1; min_gain_to_split=0.0701; min_sum_hessian_in_leaf=1.38; max_depth=8; max_bin=175 : y = 0.933 : 287.1 secs : infill_ei
#
# Sat Oct 11 14:38:36 2025 AUC 0.92907661656393
#
# [mbo] 13: num_iterations=1059; learning_rate=0.0594; feature_fraction=0.457; num_leaves=148; min_data_in_leaf=2645; lambda_l1=1.43; lambda_l2=7.13; bagging_fraction=0.799; bagging_freq=0; min_gain_to_split=0.0184; min_sum_hessian_in_leaf=3.06; max_depth=6; max_bin=145 : y = 0.929 : 141.9 secs : infill_ei
#
# Sat Oct 11 14:48:06 2025 AUC 0.935422883957722
#
# [mbo] 14: num_iterations=1568; learning_rate=0.0286; feature_fraction=0.677; num_leaves=137; min_data_in_leaf=59; lambda_l1=1.91; lambda_l2=4.64; bagging_fraction=0.724; bagging_freq=1; min_gain_to_split=0.0792; min_sum_hessian_in_leaf=0.669; max_depth=13; max_bin=201 : y = 0.935 : 569.6 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Sat Oct 11 14:53:38 2025 AUC 0.932428982819621
#
# [mbo] 15: num_iterations=1445; learning_rate=0.041; feature_fraction=0.466; num_leaves=198; min_data_in_leaf=76; lambda_l1=4.06; lambda_l2=5.36; bagging_fraction=0.684; bagging_freq=1; min_gain_to_split=0.139; min_sum_hessian_in_leaf=0.761; max_depth=14; max_bin=169 : y = 0.932 : 325.1 secs : infill_ei
#
# Sat Oct 11 14:59:30 2025 AUC 0.932765330956519
#
# [mbo] 16: num_iterations=1861; learning_rate=0.0484; feature_fraction=0.534; num_leaves=128; min_data_in_leaf=14; lambda_l1=2.54; lambda_l2=4.86; bagging_fraction=0.711; bagging_freq=2; min_gain_to_split=0.381; min_sum_hessian_in_leaf=2.59; max_depth=15; max_bin=178 : y = 0.933 : 350.1 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Sat Oct 11 15:02:33 2025 AUC 0.923848455167935
#
# [mbo] 17: num_iterations=1543; learning_rate=0.0505; feature_fraction=0.484; num_leaves=43; min_data_in_leaf=655; lambda_l1=0.27; lambda_l2=8.56; bagging_fraction=0.701; bagging_freq=0; min_gain_to_split=9.82; min_sum_hessian_in_leaf=5.4; max_depth=6; max_bin=298 : y = 0.924 : 176.2 secs : infill_ei
#
# Sat Oct 11 15:11:18 2025 AUC 0.934021984195482
#
# [mbo] 18: num_iterations=1617; learning_rate=0.0293; feature_fraction=0.631; num_leaves=71; min_data_in_leaf=10; lambda_l1=3.97; lambda_l2=2.76; bagging_fraction=0.624; bagging_freq=3; min_gain_to_split=0.00639; min_sum_hessian_in_leaf=1.72; max_depth=12; max_bin=246 : y = 0.934 : 523.8 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Sat Oct 11 15:14:48 2025 AUC 0.934314666796302
#
# [mbo] 19: num_iterations=1462; learning_rate=0.0538; feature_fraction=0.646; num_leaves=212; min_data_in_leaf=32; lambda_l1=0.411; lambda_l2=2.77; bagging_fraction=0.819; bagging_freq=5; min_gain_to_split=0.00158; min_sum_hessian_in_leaf=6.92; max_depth=8; max_bin=83 : y = 0.934 : 202.8 secs : infill_ei
#
# Sat Oct 11 15:19:49 2025 AUC 0.934383854640721
#
# [mbo] 20: num_iterations=1609; learning_rate=0.0586; feature_fraction=0.719; num_leaves=141; min_data_in_leaf=31; lambda_l1=3.78; lambda_l2=0.0353; bagging_fraction=0.962; bagging_freq=5; min_gain_to_split=0.00756; min_sum_hessian_in_leaf=6.88; max_depth=9; max_bin=144 : y = 0.934 : 300.3 secs : infill_ei
#
# Sat Oct 11 15:26:00 2025 AUC 0.936318927986351
#
# [mbo] 21: num_iterations=1480; learning_rate=0.0328; feature_fraction=0.764; num_leaves=53; min_data_in_leaf=16; lambda_l1=0.482; lambda_l2=1.36; bagging_fraction=0.919; bagging_freq=3; min_gain_to_split=0.016; min_sum_hessian_in_leaf=6.99; max_depth=12; max_bin=169 : y = 0.936 : 369.5 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Sat Oct 11 15:31:44 2025 AUC 0.934287294636211
#
# [mbo] 22: num_iterations=1385; learning_rate=0.058; feature_fraction=0.55; num_leaves=250; min_data_in_leaf=16; lambda_l1=0.159; lambda_l2=7.62; bagging_fraction=0.95; bagging_freq=3; min_gain_to_split=0.293; min_sum_hessian_in_leaf=2.26; max_depth=9; max_bin=433 : y = 0.934 : 338.0 secs : infill_ei
#
# Sat Oct 11 15:36:56 2025 AUC 0.933022654743656
#
# [mbo] 23: num_iterations=1499; learning_rate=0.0394; feature_fraction=0.684; num_leaves=91; min_data_in_leaf=230; lambda_l1=2.85; lambda_l2=2.2; bagging_fraction=0.872; bagging_freq=4; min_gain_to_split=0.16; min_sum_hessian_in_leaf=5.42; max_depth=15; max_bin=145 : y = 0.933 : 310.6 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Sat Oct 11 15:42:31 2025 AUC 0.933778906218173
#
# [mbo] 24: num_iterations=1325; learning_rate=0.0584; feature_fraction=0.583; num_leaves=250; min_data_in_leaf=274; lambda_l1=0.375; lambda_l2=7.53; bagging_fraction=0.924; bagging_freq=4; min_gain_to_split=0.0249; min_sum_hessian_in_leaf=1.13; max_depth=10; max_bin=166 : y = 0.934 : 328.0 secs : infill_ei
#
# Sat Oct 11 15:49:38 2025 AUC 0.936118103092515
#
# [mbo] 25: num_iterations=1705; learning_rate=0.0502; feature_fraction=0.764; num_leaves=112; min_data_in_leaf=13; lambda_l1=0.882; lambda_l2=2.38; bagging_fraction=0.985; bagging_freq=4; min_gain_to_split=0.0243; min_sum_hessian_in_leaf=3.55; max_depth=9; max_bin=216 : y = 0.936 : 426.5 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Sat Oct 11 15:53:28 2025 AUC 0.930405348533124
#
# [mbo] 26: num_iterations=1245; learning_rate=0.0597; feature_fraction=0.62; num_leaves=114; min_data_in_leaf=1797; lambda_l1=2.19; lambda_l2=6.12; bagging_fraction=0.979; bagging_freq=2; min_gain_to_split=0.119; min_sum_hessian_in_leaf=1; max_depth=9; max_bin=499 : y = 0.93 : 222.8 secs : infill_ei
#
# Sat Oct 11 15:55:43 2025 AUC 0.930525447329988
#
# [mbo] 27: num_iterations=1282; learning_rate=0.0452; feature_fraction=0.797; num_leaves=64; min_data_in_leaf=11; lambda_l1=0.218; lambda_l2=1.17; bagging_fraction=0.77; bagging_freq=4; min_gain_to_split=2.63; min_sum_hessian_in_leaf=7.34; max_depth=11; max_bin=501 : y = 0.931 : 133.6 secs : infill_ei
#
# Sat Oct 11 16:03:05 2025 AUC 0.937109902635397
#
# [mbo] 28: num_iterations=1502; learning_rate=0.0565; feature_fraction=0.714; num_leaves=117; min_data_in_leaf=131; lambda_l1=0.0764; lambda_l2=0.466; bagging_fraction=0.945; bagging_freq=1; min_gain_to_split=0.000949; min_sum_hessian_in_leaf=3.92; max_depth=13; max_bin=210 : y = 0.937 : 440.9 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Sat Oct 11 16:10:16 2025 AUC 0.935851446484559
#
# [mbo] 29: num_iterations=1600; learning_rate=0.058; feature_fraction=0.61; num_leaves=88; min_data_in_leaf=13; lambda_l1=1.71; lambda_l2=3.06; bagging_fraction=0.921; bagging_freq=1; min_gain_to_split=0.0656; min_sum_hessian_in_leaf=2.1; max_depth=10; max_bin=291 : y = 0.936 : 423.3 secs : infill_ei
#
# Sat Oct 11 16:14:55 2025 AUC 0.933226424360373
#
# [mbo] 30: num_iterations=1704; learning_rate=0.0175; feature_fraction=0.769; num_leaves=36; min_data_in_leaf=19; lambda_l1=0.479; lambda_l2=0.11; bagging_fraction=0.919; bagging_freq=1; min_gain_to_split=1.39; min_sum_hessian_in_leaf=2.41; max_depth=11; max_bin=273 : y = 0.933 : 278.3 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Sat Oct 11 16:21:43 2025 AUC 0.934911979606847
#
# [mbo] 31: num_iterations=1962; learning_rate=0.0409; feature_fraction=0.733; num_leaves=180; min_data_in_leaf=10; lambda_l1=4.1; lambda_l2=1.59; bagging_fraction=0.959; bagging_freq=1; min_gain_to_split=0.0759; min_sum_hessian_in_leaf=7.29; max_depth=12; max_bin=204 : y = 0.935 : 400.4 secs : infill_ei
#
# Sat Oct 11 16:26:35 2025 AUC 0.934402656236544
#
# [mbo] 32: num_iterations=1516; learning_rate=0.0551; feature_fraction=0.729; num_leaves=112; min_data_in_leaf=10; lambda_l1=0.122; lambda_l2=1.93; bagging_fraction=0.985; bagging_freq=1; min_gain_to_split=0.0555; min_sum_hessian_in_leaf=7.35; max_depth=9; max_bin=159 : y = 0.934 : 290.8 secs : infill_ei
#
# Saved the current state after iteration 33 in the file bayesiana.RDATA.
#
# Sat Oct 11 16:27:38 2025 AUC 0.923863213944091
#
# [mbo] 33: num_iterations=599; learning_rate=0.0319; feature_fraction=0.622; num_leaves=10; min_data_in_leaf=55; lambda_l1=1.05; lambda_l2=9.87; bagging_fraction=0.506; bagging_freq=0; min_gain_to_split=7.84; min_sum_hessian_in_leaf=0.653; max_depth=8; max_bin=482 : y = 0.924 : 54.3 secs : infill_ei
#
# Sat Oct 11 16:37:06 2025 AUC 0.934021397658101
#
# [mbo] 34: num_iterations=1693; learning_rate=0.036; feature_fraction=0.631; num_leaves=195; min_data_in_leaf=18; lambda_l1=0.425; lambda_l2=0.0351; bagging_fraction=0.658; bagging_freq=3; min_gain_to_split=0.00579; min_sum_hessian_in_leaf=7.32; max_depth=13; max_bin=275 : y = 0.934 : 566.7 secs : infill_ei
#
# Saved the current state after iteration 35 in the file bayesiana.RDATA.
#
# Sat Oct 11 16:41:35 2025 AUC 0.933340184157119
#
# [mbo] 35: num_iterations=1797; learning_rate=0.0526; feature_fraction=0.633; num_leaves=216; min_data_in_leaf=16; lambda_l1=3.4; lambda_l2=0.0437; bagging_fraction=0.929; bagging_freq=2; min_gain_to_split=0.158; min_sum_hessian_in_leaf=0.834; max_depth=13; max_bin=271 : y = 0.933 : 261.8 secs : infill_ei
#
# Sat Oct 11 16:48:08 2025 AUC 0.935465063879487
#
# [mbo] 36: num_iterations=1353; learning_rate=0.059; feature_fraction=0.706; num_leaves=36; min_data_in_leaf=12; lambda_l1=0.22; lambda_l2=2.74; bagging_fraction=0.801; bagging_freq=2; min_gain_to_split=0.0053; min_sum_hessian_in_leaf=0.122; max_depth=13; max_bin=306 : y = 0.935 : 391.2 secs : infill_ei
#
# Saved the current state after iteration 37 in the file bayesiana.RDATA.
#
# Sat Oct 11 16:54:11 2025 AUC 0.935233255605018
#
# [mbo] 37: num_iterations=1559; learning_rate=0.0378; feature_fraction=0.67; num_leaves=97; min_data_in_leaf=15; lambda_l1=0.147; lambda_l2=3.16; bagging_fraction=0.963; bagging_freq=3; min_gain_to_split=0.24; min_sum_hessian_in_leaf=1.36; max_depth=12; max_bin=258 : y = 0.935 : 355.3 secs : infill_ei
#
# Sat Oct 11 16:58:35 2025 AUC 0.933565588974829
#
# [mbo] 38: num_iterations=2015; learning_rate=0.0496; feature_fraction=0.717; num_leaves=84; min_data_in_leaf=17; lambda_l1=3.19; lambda_l2=0.722; bagging_fraction=0.659; bagging_freq=0; min_gain_to_split=0.124; min_sum_hessian_in_leaf=2.78; max_depth=14; max_bin=370 : y = 0.934 : 262.3 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesiana.RDATA.
#
# Sat Oct 11 17:07:22 2025 AUC 0.93539362477288
#
# [mbo] 39: num_iterations=1553; learning_rate=0.0592; feature_fraction=0.728; num_leaves=115; min_data_in_leaf=11; lambda_l1=0.5; lambda_l2=0.413; bagging_fraction=0.968; bagging_freq=5; min_gain_to_split=0.0245; min_sum_hessian_in_leaf=7.06; max_depth=14; max_bin=301 : y = 0.935 : 520.1 secs : infill_ei
#
# Sat Oct 11 17:13:42 2025 AUC 0.935912485021043
#
# [mbo] 40: num_iterations=1575; learning_rate=0.0499; feature_fraction=0.723; num_leaves=44; min_data_in_leaf=12; lambda_l1=1.16; lambda_l2=0.836; bagging_fraction=0.831; bagging_freq=2; min_gain_to_split=0.0165; min_sum_hessian_in_leaf=3.31; max_depth=12; max_bin=169 : y = 0.936 : 377.9 secs : infill_ei
#
# Saved the current state after iteration 41 in the file bayesiana.RDATA.
#
# Sat Oct 11 17:21:47 2025 AUC 0.934763999685567
#
# [mbo] 41: num_iterations=1394; learning_rate=0.0594; feature_fraction=0.554; num_leaves=134; min_data_in_leaf=145; lambda_l1=0.777; lambda_l2=1.27; bagging_fraction=0.86; bagging_freq=1; min_gain_to_split=0.00349; min_sum_hessian_in_leaf=4.21; max_depth=12; max_bin=287 : y = 0.935 : 480.1 secs : infill_ei
#
# Sat Oct 11 17:23:27 2025 AUC 0.926695439173095
#
# [mbo] 42: num_iterations=895; learning_rate=0.055; feature_fraction=0.654; num_leaves=161; min_data_in_leaf=2256; lambda_l1=1.41; lambda_l2=9.44; bagging_fraction=0.64; bagging_freq=2; min_gain_to_split=0.64; min_sum_hessian_in_leaf=2.34; max_depth=-1; max_bin=409 : y = 0.927 : 97.7 secs : infill_ei
#
# Sat Oct 11 17:38:30 2025 AUC 0.935266538064329
#
# [mbo] 43: num_iterations=1866; learning_rate=0.0231; feature_fraction=0.492; num_leaves=119; min_data_in_leaf=12; lambda_l1=3.43; lambda_l2=8.35; bagging_fraction=0.917; bagging_freq=2; min_gain_to_split=0.00123; min_sum_hessian_in_leaf=3.38; max_depth=13; max_bin=399 : y = 0.935 : 901.4 secs : infill_ei
#
# Saved the current state after iteration 44 in the file bayesiana.RDATA.
#
# Sat Oct 11 17:45:40 2025 AUC 0.935159584682771
#
# [mbo] 44: num_iterations=1974; learning_rate=0.0586; feature_fraction=0.748; num_leaves=109; min_data_in_leaf=19; lambda_l1=0.282; lambda_l2=0.196; bagging_fraction=0.996; bagging_freq=2; min_gain_to_split=0.0395; min_sum_hessian_in_leaf=3.93; max_depth=14; max_bin=342 : y = 0.935 : 422.1 secs : infill_ei
#
# Sat Oct 11 17:55:00 2025 AUC 0.934796309709357
#
# [mbo] 45: num_iterations=1557; learning_rate=0.0543; feature_fraction=0.682; num_leaves=50; min_data_in_leaf=22; lambda_l1=0.362; lambda_l2=7.99; bagging_fraction=0.94; bagging_freq=0; min_gain_to_split=0.0262; min_sum_hessian_in_leaf=3.61; max_depth=13; max_bin=325 : y = 0.935 : 559.0 secs : infill_ei
#
# Saved the current state after iteration 46 in the file bayesiana.RDATA.
#
# Sat Oct 11 18:07:27 2025 AUC 0.936804410306441
#
# [mbo] 46: num_iterations=1462; learning_rate=0.0469; feature_fraction=0.795; num_leaves=136; min_data_in_leaf=10; lambda_l1=1.32; lambda_l2=2.06; bagging_fraction=0.95; bagging_freq=1; min_gain_to_split=0.00983; min_sum_hessian_in_leaf=2.08; max_depth=12; max_bin=404 : y = 0.937 : 739.4 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Sat Oct 11 18:11:41 2025 AUC 0.933450348319299
#
# [mbo] 47: num_iterations=1724; learning_rate=0.0236; feature_fraction=0.647; num_leaves=233; min_data_in_leaf=23; lambda_l1=1.17; lambda_l2=7.08; bagging_fraction=0.879; bagging_freq=0; min_gain_to_split=1.07; min_sum_hessian_in_leaf=3.48; max_depth=14; max_bin=355 : y = 0.933 : 247.1 secs : infill_ei
#
# Sat Oct 11 18:13:15 2025 AUC 0.923364254003072
#
# [mbo] 48: num_iterations=1775; learning_rate=0.0541; feature_fraction=0.76; num_leaves=136; min_data_in_leaf=12; lambda_l1=4.94; lambda_l2=5.24; bagging_fraction=0.908; bagging_freq=1; min_gain_to_split=0.00246; min_sum_hessian_in_leaf=3.05; max_depth=1; max_bin=461 : y = 0.923 : 92.4 secs : infill_ei
#
# Sat Oct 11 18:25:40 2025 AUC 0.935799835270183
#
# [mbo] 49: num_iterations=1460; learning_rate=0.0417; feature_fraction=0.631; num_leaves=71; min_data_in_leaf=26; lambda_l1=1.09; lambda_l2=5.86; bagging_fraction=0.915; bagging_freq=5; min_gain_to_split=0.000559; min_sum_hessian_in_leaf=1.2; max_depth=12; max_bin=425 : y = 0.936 : 743.7 secs : infill_ei
#
# Saved the current state after iteration 50 in the file bayesiana.RDATA.
#
# Sat Oct 11 18:37:03 2025 AUC 0.933140865733071
#
# [mbo] 50: num_iterations=1638; learning_rate=0.0346; feature_fraction=0.587; num_leaves=71; min_data_in_leaf=182; lambda_l1=0.926; lambda_l2=7.62; bagging_fraction=0.635; bagging_freq=1; min_gain_to_split=0.114; min_sum_hessian_in_leaf=1.01; max_depth=15; max_bin=440 : y = 0.933 : 676.7 secs : infill_ei
#
# Saved the current state after iteration 51 in the file bayesiana.RDATA.
#
# Sat Oct 11 18:43:20 2025 AUC 0.93281094024088
#
# [mbo] 51: num_iterations=1542; learning_rate=0.0565; feature_fraction=0.584; num_leaves=112; min_data_in_leaf=18; lambda_l1=0.853; lambda_l2=8.76; bagging_fraction=0.667; bagging_freq=5; min_gain_to_split=0.572; min_sum_hessian_in_leaf=0.632; max_depth=-1; max_bin=340 : y = 0.933 : 369.3 secs : infill_ei
#
# Sat Oct 11 18:58:52 2025 AUC 0.937200574370663
#
# [mbo] 52: num_iterations=1465; learning_rate=0.0204; feature_fraction=0.653; num_leaves=128; min_data_in_leaf=22; lambda_l1=2.86; lambda_l2=7.94; bagging_fraction=0.799; bagging_freq=0; min_gain_to_split=0.00339; min_sum_hessian_in_leaf=0.794; max_depth=11; max_bin=404 : y = 0.937 : 930.1 secs : infill_ei
#
# Saved the current state after iteration 53 in the file bayesiana.RDATA.
#
# Sat Oct 11 19:05:24 2025 AUC 0.932739579034652
#
# [mbo] 53: num_iterations=1460; learning_rate=0.0248; feature_fraction=0.562; num_leaves=124; min_data_in_leaf=54; lambda_l1=0.283; lambda_l2=7.52; bagging_fraction=0.762; bagging_freq=5; min_gain_to_split=0.0268; min_sum_hessian_in_leaf=0.615; max_depth=6; max_bin=474 : y = 0.933 : 384.7 secs : infill_ei
#
# Sat Oct 11 19:17:38 2025 AUC 0.935459571743023
#
# [mbo] 54: num_iterations=1445; learning_rate=0.0301; feature_fraction=0.678; num_leaves=87; min_data_in_leaf=34; lambda_l1=3.97; lambda_l2=7.13; bagging_fraction=0.979; bagging_freq=1; min_gain_to_split=0.0138; min_sum_hessian_in_leaf=0.907; max_depth=13; max_bin=409 : y = 0.935 : 732.2 secs : infill_ei
#
# Saved the current state after iteration 55 in the file bayesiana.RDATA.
#
# Sat Oct 11 19:18:30 2025 AUC 0.92747491969208
#
# [mbo] 55: num_iterations=358; learning_rate=0.0519; feature_fraction=0.75; num_leaves=25; min_data_in_leaf=1256; lambda_l1=0.25; lambda_l2=7.79; bagging_fraction=0.52; bagging_freq=2; min_gain_to_split=0.87; min_sum_hessian_in_leaf=5.5; max_depth=11; max_bin=312 : y = 0.927 : 43.9 secs : infill_ei
#
# Sat Oct 11 19:21:19 2025 AUC 0.933620104400785
#
# [mbo] 56: num_iterations=1414; learning_rate=0.0591; feature_fraction=0.749; num_leaves=163; min_data_in_leaf=49; lambda_l1=0.724; lambda_l2=2.85; bagging_fraction=0.803; bagging_freq=5; min_gain_to_split=0.71; min_sum_hessian_in_leaf=5.84; max_depth=12; max_bin=164 : y = 0.934 : 166.9 secs : infill_ei
#
# Sat Oct 11 19:36:47 2025 AUC 0.934388651575168
#
# [mbo] 57: num_iterations=1851; learning_rate=0.00798; feature_fraction=0.679; num_leaves=216; min_data_in_leaf=22; lambda_l1=2.12; lambda_l2=4.01; bagging_fraction=0.906; bagging_freq=5; min_gain_to_split=0.0344; min_sum_hessian_in_leaf=7.05; max_depth=12; max_bin=391 : y = 0.934 : 926.4 secs : infill_ei
#
# Saved the current state after iteration 58 in the file bayesiana.RDATA.
#
# Sat Oct 11 19:46:48 2025 AUC 0.936784089117163
#
# [mbo] 58: num_iterations=1454; learning_rate=0.0417; feature_fraction=0.703; num_leaves=106; min_data_in_leaf=11; lambda_l1=1.16; lambda_l2=1.02; bagging_fraction=0.948; bagging_freq=2; min_gain_to_split=0.0263; min_sum_hessian_in_leaf=3.72; max_depth=11; max_bin=324 : y = 0.937 : 592.9 secs : infill_ei
#
# Sat Oct 11 19:58:34 2025 AUC 0.934525498687047
#
# [mbo] 59: num_iterations=1657; learning_rate=0.0183; feature_fraction=0.703; num_leaves=65; min_data_in_leaf=20; lambda_l1=3.48; lambda_l2=1.18; bagging_fraction=0.946; bagging_freq=5; min_gain_to_split=0.00129; min_sum_hessian_in_leaf=6.75; max_depth=11; max_bin=367 : y = 0.935 : 704.7 secs : infill_ei
#
# Saved the current state after iteration 60 in the file bayesiana.RDATA.
#
# Sat Oct 11 20:06:41 2025 AUC 0.935592891146201
#
# [mbo] 60: num_iterations=1926; learning_rate=0.0269; feature_fraction=0.757; num_leaves=44; min_data_in_leaf=12; lambda_l1=1.6; lambda_l2=1.11; bagging_fraction=0.779; bagging_freq=5; min_gain_to_split=0.00534; min_sum_hessian_in_leaf=7.49; max_depth=11; max_bin=201 : y = 0.936 : 479.3 secs : infill_ei
#
# Sat Oct 11 20:12:57 2025 AUC 0.936093300183824
#
# [mbo] 61: num_iterations=1878; learning_rate=0.0537; feature_fraction=0.516; num_leaves=119; min_data_in_leaf=15; lambda_l1=1.54; lambda_l2=0.607; bagging_fraction=0.991; bagging_freq=5; min_gain_to_split=0.0412; min_sum_hessian_in_leaf=6.88; max_depth=13; max_bin=230 : y = 0.936 : 374.9 secs : infill_ei
#
# Saved the current state after iteration 62 in the file bayesiana.RDATA.
#
# Sat Oct 11 20:19:37 2025 AUC 0.932560360089376
#
# [mbo] 62: num_iterations=1441; learning_rate=0.0535; feature_fraction=0.681; num_leaves=73; min_data_in_leaf=659; lambda_l1=1.07; lambda_l2=0.508; bagging_fraction=0.636; bagging_freq=0; min_gain_to_split=0.0133; min_sum_hessian_in_leaf=3.29; max_depth=12; max_bin=362 : y = 0.933 : 391.9 secs : infill_ei
#
# Sat Oct 11 20:25:02 2025 AUC 0.935584629307485
#
# [mbo] 63: num_iterations=2025; learning_rate=0.0162; feature_fraction=0.726; num_leaves=252; min_data_in_leaf=36; lambda_l1=0.757; lambda_l2=0.504; bagging_fraction=0.75; bagging_freq=4; min_gain_to_split=0.0128; min_sum_hessian_in_leaf=6.74; max_depth=8; max_bin=105 : y = 0.936 : 323.3 secs : infill_ei
#
# Saved the current state after iteration 64 in the file bayesiana.RDATA.
#
# Sat Oct 11 20:33:44 2025 AUC 0.936063710320664
#
# [mbo] 64: num_iterations=2018; learning_rate=0.0369; feature_fraction=0.49; num_leaves=141; min_data_in_leaf=87; lambda_l1=1.34; lambda_l2=1.16; bagging_fraction=0.779; bagging_freq=5; min_gain_to_split=0.00967; min_sum_hessian_in_leaf=0.887; max_depth=9; max_bin=169 : y = 0.936 : 515.1 secs : infill_ei
#
# Sat Oct 11 20:49:34 2025 AUC 0.936284452988129
#
# [mbo] 65: num_iterations=1554; learning_rate=0.0242; feature_fraction=0.646; num_leaves=234; min_data_in_leaf=23; lambda_l1=1.17; lambda_l2=7.66; bagging_fraction=0.663; bagging_freq=0; min_gain_to_split=0.00214; min_sum_hessian_in_leaf=1.53; max_depth=10; max_bin=504 : y = 0.936 : 948.7 secs : infill_ei
#
# Saved the current state after iteration 66 in the file bayesiana.RDATA.
#
# Sat Oct 11 21:01:58 2025 AUC 0.937796466476681
#
# [mbo] 66: num_iterations=2000; learning_rate=0.0211; feature_fraction=0.777; num_leaves=134; min_data_in_leaf=15; lambda_l1=1.29; lambda_l2=0.307; bagging_fraction=0.891; bagging_freq=0; min_gain_to_split=0.011; min_sum_hessian_in_leaf=1.72; max_depth=11; max_bin=198 : y = 0.938 : 736.2 secs : infill_ei
#
# Saved the current state after iteration 67 in the file bayesiana.RDATA.
#
# Sat Oct 11 21:10:01 2025 AUC 0.934633551769489
#
# [mbo] 67: num_iterations=2044; learning_rate=0.0225; feature_fraction=0.689; num_leaves=103; min_data_in_leaf=271; lambda_l1=3.17; lambda_l2=7.97; bagging_fraction=0.965; bagging_freq=5; min_gain_to_split=0.0247; min_sum_hessian_in_leaf=2.47; max_depth=11; max_bin=119 : y = 0.935 : 474.6 secs : infill_ei
#
# Sat Oct 11 21:21:03 2025 AUC 0.93517920832665
#
# [mbo] 68: num_iterations=1996; learning_rate=0.0538; feature_fraction=0.584; num_leaves=184; min_data_in_leaf=141; lambda_l1=1.75; lambda_l2=7.91; bagging_fraction=0.85; bagging_freq=0; min_gain_to_split=0.00212; min_sum_hessian_in_leaf=0.256; max_depth=11; max_bin=321 : y = 0.935 : 659.7 secs : infill_ei
#
# Saved the current state after iteration 69 in the file bayesiana.RDATA.
#
# Sat Oct 11 21:36:08 2025 AUC 0.934783521999627
#
# [mbo] 69: num_iterations=2033; learning_rate=0.00686; feature_fraction=0.595; num_leaves=209; min_data_in_leaf=17; lambda_l1=3.03; lambda_l2=0.443; bagging_fraction=0.641; bagging_freq=0; min_gain_to_split=0.00467; min_sum_hessian_in_leaf=4.02; max_depth=10; max_bin=322 : y = 0.935 : 897.1 secs : infill_ei
#
# Saved the current state after iteration 70 in the file bayesiana.RDATA.
#
# Sat Oct 11 21:57:02 2025 AUC 0.934444393432589
#
# [mbo] 70: num_iterations=1897; learning_rate=0.00967; feature_fraction=0.709; num_leaves=232; min_data_in_leaf=14; lambda_l1=1.99; lambda_l2=7.28; bagging_fraction=0.609; bagging_freq=5; min_gain_to_split=0.0553; min_sum_hessian_in_leaf=2.69; max_depth=-1; max_bin=396 : y = 0.934 : 1246.1 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"          "learning_rate"
#  [3] "feature_fraction"        "num_leaves"
#  [5] "min_data_in_leaf"        "lambda_l1"
#  [7] "lambda_l2"               "bagging_fraction"
#  [9] "bagging_freq"            "min_gain_to_split"
# [11] "min_sum_hessian_in_leaf" "max_depth"
# [13] "max_bin"                 "y"
# [15] "dob"                     "eol"
# [17] "error.message"           "exec.time"
# [19] "ei"                      "error.model"
# [21] "train.time"              "prop.type"
# [23] "propose.time"            "se"
# [25] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           2000     0.0210974        0.7768085        134               15
#    lambda_l1 lambda_l2 bagging_fraction bagging_freq min_gain_to_split
#        <num>     <num>            <num>        <int>             <num>
# 1:   1.28843 0.3073382        0.8910694            0        0.01095669
#    min_sum_hessian_in_leaf max_depth max_bin
#                      <num>     <int>   <int>
# 1:                1.724301        11     198
# [1] 0.9377965

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la  optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train_final]
dataset_train[,.N,clase_ternaria]
# Out:
#   clase_ternaria N
# 1 CONTINUA       481491
# 2 BAJA+2           2808
# 3 BAJA+1           2492

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 99991
#
# $max_depth
# [1] 11
#
# $min_gain_to_split
# [1] 0.01095669
#
# $min_sum_hessian_in_leaf
# [1] 1.724301
#
# $lambda_l1
# [1] 1.28843
#
# $lambda_l2
# [1] 0.3073382
#
# $max_bin
# [1] 198
#
# $bagging_fraction
# [1] 0.8910694
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2000
#
# $learning_rate
# [1] 0.0210974
#
# $feature_fraction
# [1] 0.7768085
#
# $num_leaves
# [1] 134
#
# $min_data_in_leaf
# [1] 15
#
# $bagging_freq
# [1] 0

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria y mucho menos cross validation.

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
# instalo y cargo la libreria  primes
if (!require("primes")) install.packages("primes")
require("primes")

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(99991) # inicializo con mi primer semilla
# me quedo con por ejemplo 20 primos al azar
semillas_finales <- sample(primos, 10 )
print( semillas_finales )
# Out:
#  [1] 344417 905647 164371 908359 395287 271729 877771 102761 859423 246049

# %%
# ALTERNATIVA
PARAM$future = c(202104)
dfuture <- dataset[foto_mes %in% PARAM$future]

# 1: Inicializar las listas necesarias para el loop
modelos_finales <- list()
predicciones_finales <- list()
resultados_ganancia_semilla <- list()

# Asegurar que PARAM$cortes está definido antes de los loops
PARAM$cortes <- seq(6000, 13000, by= 100)

# ----------------------------------------------------------------------
# LOOP PRINCIPAL: ENTRENAMIENTO Y EVALUACIÓN POR SEMILLA
# ----------------------------------------------------------------------
for (sem in semillas_finales) {
    param_normalizado$seed <- sem

    # ENTRENAR
    modelo <- lgb.train(
      data = dtrain_final,
      param = param_normalizado
    )

    # PREDECIR
    pred <- predict(
      modelo,
      data.matrix(dfuture[, campos_buenos, with=FALSE])
    )

    # Guardar la predicción y el modelo
    modelos_finales[[as.character(sem)]] <- modelo
    predicciones_finales[[as.character(sem)]] <- pred


    # EVALUAR GANANCIA INDIVIDUAL

    # Usar la variable 'pred' local o la que acabamos de guardar
    tb_pred_individual <- dfuture[, list(numero_de_cliente, foto_mes)]
    tb_pred_individual[, prob := pred ] # Usar la predicción local 'pred'

    # Ordenar por probabilidad descendente
    setorder(tb_pred_individual, -prob)

    drealidad <- realidad_inicializar( dfuture, PARAM)

    ganancias_semilla_actual <- data.table(
        semilla = sem,
        envios = integer(),
        ganancia_total = numeric(),
        ganancia_public = numeric(),
        ganancia_private = numeric()
    )

    # Evaluar la ganancia para todos los cortes
    for (envios in PARAM$cortes) {
        tb_pred_individual[, Predicted := 0L]
        tb_pred_individual[1:envios, Predicted := 1L]

        res <- realidad_evaluar( drealidad, tb_pred_individual)

        # Guardar los resultados
        ganancias_semilla_actual <- rbind(ganancias_semilla_actual,
            list(sem, envios, res$total, res$public, res$private)
        )
    }

    # Almacenar el data.table de ganancias para esta semilla
    resultados_ganancia_semilla[[as.character(sem)]] <- ganancias_semilla_actual
}

# %%
require( "data.table" )

# 1. Extraer todas las predicciones de probabilidad de la lista
# La lista 'predicciones_finales' contiene un vector de probabilidades por semilla
lista_de_probs <- predicciones_finales

# 2. Convertir los vectores de probabilidad a un data.table
# Necesitamos una columna de ID (numero_de_cliente) para hacer el merge/promedio

# Crear el data.table base usando los identificadores de cliente del dfuture
dt_ensemble_202104 <- dfuture[, list(numero_de_cliente, foto_mes)]


# 3. Iterar sobre las predicciones y agregar cada una como una nueva columna
i <- 1
for (sem in names(lista_de_probs)) {
    # Crear un data.table temporal con la probabilidad y el ID
    dt_temp <- data.table(
        numero_de_cliente = dt_ensemble_202104$numero_de_cliente,
        # Aseguramos el nombre de columna dinámico, ej: 'prob_17', 'prob_2025'
        prob = lista_de_probs[[sem]]
    )

    # Renombrar la columna de probabilidad para evitar conflictos en el merge
    setnames(dt_temp, "prob", paste0("prob_", sem))

    # Mergear la nueva probabilidad al data.table principal
    dt_ensemble_202104 <- merge(
        dt_ensemble_202104,
        dt_temp,
        by = "numero_de_cliente"
    )
    i <- i + 1
}


# 4. Calcular la Probabilidad Promedio (Ensemble Final)
# Seleccionamos todas las columnas que empiezan con 'prob_'
cols_probabilidad <- grep("^prob_", names(dt_ensemble_202104), value = TRUE)

dt_ensemble_202104[, prob_ensemble := rowMeans(.SD), .SDcols = cols_probabilidad]

# 5. Generar la tabla de predicción final (solo ID y probabilidad)
prediccion_202104_ensamble <- dt_ensemble_202104[,
    list(numero_de_cliente, foto_mes, prob = prob_ensemble)
]

cat("Predicción ensemble para 202104 calculada con éxito.\n")
# Out:
# Predicción ensemble para 202104 calculada con éxito.

# %%
# Definir el nombre del archivo de salida
archivo_prediccion <- paste0("prediccion_202104_ensemble_", PARAM$ID_MODELO, ".txt")

# Usar la función fwrite para guardar el data.table en formato .txt de forma eficiente
fwrite(prediccion_202104_ensamble,
       file = archivo_prediccion,
       sep = "\t",
       col.names = TRUE # Incluir los nombres de las columnas (numero_de_cliente, foto_mes, prob)
)

cat("Predicción ensemble 202104 guardada en:", archivo_prediccion, "\n")
# Out:
# Predicción ensemble 202104 guardada en: prediccion_202104_ensemble_.txt

# %% [markdown]
# ### Scoring

# %% [markdown]
# Kaggle Competition Submit

# %%
PARAM$cortes <- seq(6000, 13000, by= 100)
PARAM$cortes
# Out:
#  [1]  6000  6100  6200  6300  6400  6500  6600  6700  6800  6900  7000  7100
# [13]  7200  7300  7400  7500  7600  7700  7800  7900  8000  8100  8200  8300
# [25]  8400  8500  8600  8700  8800  8900  9000  9100  9200  9300  9400  9500
# [37]  9600  9700  9800  9900 10000 10100 10200 10300 10400 10500 10600 10700
# [49] 10800 10900 11000 11100 11200 11300 11400 11500 11600 11700 11800 11900
# [61] 12000 12100 12200 12300 12400 12500 12600 12700 12800 12900 13000

# %%
# ----------------------------------------------------------------------
# EVALUACIÓN DEL ENSEMBLE (Se mantiene sin cambios importantes)
# ----------------------------------------------------------------------

# --- 1. Cálculo del Ensemble de Predicciones ---

# El promedio de predicciones (ensemble) se calcula sobre el total de semillas
prediccion_ensemble <- Reduce("+", predicciones_finales) / length(predicciones_finales)

# Se guarda el ensemble en la tabla de predicción final (tb_prediccion)
tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes)]
tb_prediccion[, prob := prediccion_ensemble ]

# La realidad (drealidad) se inicializa una sola vez para la evaluación
drealidad <- realidad_inicializar( dfuture, PARAM)

# Ordenar por probabilidad descendente para el scoring
setorder(tb_prediccion, -prob)


# --- 2. Evaluación de la Ganancia del Ensemble ---

ganancias_ensemble <- data.table(
    envios = integer(),
    ganancia_total = numeric(),
    ganancia_public = numeric(),
    ganancia_private = numeric()
)

# Iterar sobre los cortes definidos para encontrar el óptimo del ensemble
for (envios in PARAM$cortes) {

    tb_prediccion[, Predicted := 0L]
    tb_prediccion[1:envios, Predicted := 1L]

    # Evaluar la ganancia
    res <- realidad_evaluar( drealidad, tb_prediccion)

    # Almacenar los resultados del ensemble
    ganancias_ensemble <- rbind(ganancias_ensemble,
        list(envios, res$total, res$public, res$private)
    )

    # Imprimir el resultado de cada corte del ensemble (opcional)
    options(scipen = 999)
    cat( "ENSEMBLE Envios=", envios, "\t",
        " TOTAL=", res$total,
        " Public=", res$public,
        " Private=", res$private,
        "\n",
        sep= ""
    )
}

# --- 3. Resultados Finales del Ensemble ---

# Encontrar el corte óptimo del ensemble (el que se usará para la predicción final)
corte_optimo_ensemble <- ganancias_ensemble[which.max(ganancia_total)]

print("\n--- Resultados Óptimos del Ensemble ---")
print(corte_optimo_ensemble)
# Out:
# ENSEMBLE Envios=6000	 TOTAL=335200000 Public=267600000 Private=364171429
# ENSEMBLE Envios=6100	 TOTAL=336400000 Public=271266667 Private=364314286
# ENSEMBLE Envios=6200	 TOTAL=340000000 Public=284733333 Private=363685714
# ENSEMBLE Envios=6300	 TOTAL=343600000 Public=293266667 Private=365171429
# ENSEMBLE Envios=6400	 TOTAL=344800000 Public=299000000 Private=364428571
# ENSEMBLE Envios=6500	 TOTAL=345200000 Public=299533333 Private=364771429
# ENSEMBLE Envios=6600	 TOTAL=345600000 Public=305133333 Private=362942857
# ENSEMBLE Envios=6700	 TOTAL=345200000 Public=305400000 Private=362257143
# ENSEMBLE Envios=6800	 TOTAL=347200000 Public=306266667 Private=364742857
# ENSEMBLE Envios=6900	 TOTAL=347600000 Public=310066667 Private=363685714
# ENSEMBLE Envios=7000	 TOTAL=346400000 Public=307866667 Private=362914286
# ENSEMBLE Envios=7100	 TOTAL=347600000 Public=305333333 Private=365714286
# ENSEMBLE Envios=7200	 TOTAL=346400000 Public=303333333 Private=364857143
# ENSEMBLE Envios=7300	 TOTAL=349200000 Public=306933333 Private=367314286
# ENSEMBLE Envios=7400	 TOTAL=348800000 Public=307533333 Private=366485714
# ENSEMBLE Envios=7500	 TOTAL=347600000 Public=305333333 Private=365714286
# ENSEMBLE Envios=7600	 TOTAL=350400000 Public=305866667 Private=369485714
# ENSEMBLE Envios=7700	 TOTAL=351600000 Public=311800000 Private=368657143
# ENSEMBLE Envios=7800	 TOTAL=354400000 Public=315000000 Private=371285714
# ENSEMBLE Envios=7900	 TOTAL=355600000 Public=315600000 Private=372742857
# ENSEMBLE Envios=8000	 TOTAL=356000000 Public=316466667 Private=372942857
# ENSEMBLE Envios=8100	 TOTAL=356400000 Public=316933333 Private=373314286
# ENSEMBLE Envios=8200	 TOTAL=359200000 Public=315266667 Private=378028571
# ENSEMBLE Envios=8300	 TOTAL=358800000 Public=316133333 Private=377085714
# ENSEMBLE Envios=8400	 TOTAL=360000000 Public=319466667 Private=377371429
# ENSEMBLE Envios=8500	 TOTAL=362000000 Public=322666667 Private=378857143
# ENSEMBLE Envios=8600	 TOTAL=360800000 Public=323400000 Private=376828571
# ENSEMBLE Envios=8700	 TOTAL=363600000 Public=329600000 Private=378171429
# ENSEMBLE Envios=8800	 TOTAL=361600000 Public=327000000 Private=376428571
# ENSEMBLE Envios=8900	 TOTAL=361200000 Public=330066667 Private=374542857
# ENSEMBLE Envios=9000	 TOTAL=360800000 Public=328666667 Private=374571429
# ENSEMBLE Envios=9100	 TOTAL=360400000 Public=326733333 Private=374828571
# ENSEMBLE Envios=9200	 TOTAL=360000000 Public=327533333 Private=373914286
# ENSEMBLE Envios=9300	 TOTAL=358800000 Public=325666667 Private=373000000
# ENSEMBLE Envios=9400	 TOTAL=360800000 Public=328866667 Private=374485714
# ENSEMBLE Envios=9500	 TOTAL=359600000 Public=326533333 Private=373771429
# ENSEMBLE Envios=9600	 TOTAL=360000000 Public=330600000 Private=372600000
# ENSEMBLE Envios=9700	 TOTAL=358800000 Public=331000000 Private=370714286
# ENSEMBLE Envios=9800	 TOTAL=357600000 Public=331533333 Private=368771429
# ENSEMBLE Envios=9900	 TOTAL=362000000 Public=337333333 Private=372571429
# ENSEMBLE Envios=10000	 TOTAL=361600000 Public=335533333 Private=372771429
# ENSEMBLE Envios=10100	 TOTAL=361200000 Public=336466667 Private=371800000
# ENSEMBLE Envios=10200	 TOTAL=362400000 Public=336800000 Private=373371429
# ENSEMBLE Envios=10300	 TOTAL=361200000 Public=335000000 Private=372428571
# ENSEMBLE Envios=10400	 TOTAL=360800000 Public=335200000 Private=371771429
# ENSEMBLE Envios=10500	 TOTAL=359600000 Public=333200000 Private=370914286
# ENSEMBLE Envios=10600	 TOTAL=360800000 Public=339000000 Private=370142857
# ENSEMBLE Envios=10700	 TOTAL=359600000 Public=339666667 Private=368142857
# ENSEMBLE Envios=10800	 TOTAL=361600000 Public=343333333 Private=369428571
# ENSEMBLE Envios=10900	 TOTAL=361200000 Public=341066667 Private=369828571
# ENSEMBLE Envios=11000	 TOTAL=360000000 Public=341933333 Private=367742857
# ENSEMBLE Envios=11100	 TOTAL=361200000 Public=342466667 Private=369228571
# ENSEMBLE Envios=11200	 TOTAL=360000000 Public=340600000 Private=368314286
# ENSEMBLE Envios=11300	 TOTAL=359600000 Public=341200000 Private=367485714
# ENSEMBLE Envios=11400	 TOTAL=359200000 Public=339133333 Private=367800000
# ENSEMBLE Envios=11500	 TOTAL=361200000 Public=339733333 Private=370400000
# ENSEMBLE Envios=11600	 TOTAL=360800000 Public=340466667 Private=369514286
# ENSEMBLE Envios=11700	 TOTAL=361200000 Public=343733333 Private=368685714
# ENSEMBLE Envios=11800	 TOTAL=360800000 Public=341800000 Private=368942857
# ENSEMBLE Envios=11900	 TOTAL=361200000 Public=345466667 Private=367942857
# ENSEMBLE Envios=12000	 TOTAL=359200000 Public=343066667 Private=366114286
# ENSEMBLE Envios=12100	 TOTAL=358000000 Public=344000000 Private=364000000
# ENSEMBLE Envios=12200	 TOTAL=357600000 Public=342200000 Private=364200000
# ENSEMBLE Envios=12300	 TOTAL=361200000 Public=350533333 Private=365771429
# ENSEMBLE Envios=12400	 TOTAL=361600000 Public=351400000 Private=365971429
# ENSEMBLE Envios=12500	 TOTAL=361200000 Public=349133333 Private=366371429
# ENSEMBLE Envios=12600	 TOTAL=360800000 Public=346866667 Private=366771429
# ENSEMBLE Envios=12700	 TOTAL=359600000 Public=344866667 Private=365914286
# ENSEMBLE Envios=12800	 TOTAL=360000000 Public=342733333 Private=367400000
# ENSEMBLE Envios=12900	 TOTAL=358000000 Public=340200000 Private=365628571
# ENSEMBLE Envios=13000	 TOTAL=357600000 Public=340866667 Private=364771429
# [1] "\n--- Resultados Óptimos del Ensemble ---"
#    envios ganancia_total ganancia_public ganancia_private
#     <num>          <num>           <num>            <num>
# 1:   8700      363600000       329600000        378171429

# %%
library(data.table)
library(ggplot2)
library(scales) # Para formatear los ejes

# 1. Consolidar las ganancias de las semillas en un solo data.table
# Ya deberías tener 'df_ganancias_consolidadas' del código anterior.
# Si no, ejecútalo:
df_ganancias_consolidadas <- rbindlist(resultados_ganancia_semilla)

# 2. Calcular la ganancia promedio de las semillas
df_ganancia_promedio <- df_ganancias_consolidadas[,
    list(
        ganancia_private = mean(ganancia_private)
    ),
    by = envios]
df_ganancia_promedio[, tipo := "Promedio de Semillas"]
df_ganancia_promedio[, semilla := "Promedio"] # Para la leyenda

# 3. Preparar los datos del Ensemble (el Ensemble es el que usarás para predecir)
df_ensemble_plot <- ganancias_ensemble[, list(envios, ganancia_private = ganancia_private)]
df_ensemble_plot[, tipo := "Ensemble (Predicción Final)"]
df_ensemble_plot[, semilla := "Ensemble"] # Para la leyenda

# 4. Consolidar todas las curvas en un solo data.table para ggplot2
df_plot_final <- rbind(
    df_ganancias_consolidadas[, .(envios, ganancia_private, tipo = "Semilla Individual", semilla = as.character(semilla))],
    df_ensemble_plot[, .(envios, ganancia_private, tipo, semilla)]
)

# %%
# Exportar las ganancias de cada semilla (consolidado)
dir.create("ganancias", showWarnings = FALSE)

ruta_ganancias_por_semilla <- paste0("./ganancias/ganancia_semillas_", PARAM$experimento, "_", PARAM$semilla_primigenia, ".csv")

fwrite(df_ganancias_consolidadas,
       file = ruta_ganancias_por_semilla,
       sep = ",")

ruta_ganancias_ensemble <- paste0("./ganancias/ganancia_ensamble_", PARAM$experimento, ".csv")

fwrite(ganancias_ensemble,
       file = ruta_ganancias_ensemble,
       sep = ",")

cat("Archivos .csv guardados exitosamente en el directorio 'ganancias/'.\n")
# Out:
# Archivos .csv guardados exitosamente en el directorio 'ganancias/'.

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Oct 11 23:32:22 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# PREDICCION FINAL

# %%
# clase01
PARAM$train_final <- c(202101, 202102, 202103, 202104)
PARAM$future <- c(202106)
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]
dataset_train <- dataset[foto_mes %in% PARAM$train_final]
dataset_train[,.N,clase_ternaria]
# Out:
#   clase_ternaria N
# 1 CONTINUA       642824
# 2 BAJA+2           3938
# 3 BAJA+1           3447

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 99991
#
# $max_depth
# [1] 11
#
# $min_gain_to_split
# [1] 0.01095669
#
# $min_sum_hessian_in_leaf
# [1] 1.724301
#
# $lambda_l1
# [1] 1.28843
#
# $lambda_l2
# [1] 0.3073382
#
# $max_bin
# [1] 198
#
# $bagging_fraction
# [1] 0.8910694
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 2000
#
# $learning_rate
# [1] 0.0210974
#
# $feature_fraction
# [1] 0.7768085
#
# $num_leaves
# [1] 134
#
# $min_data_in_leaf
# [1] 15
#
# $bagging_freq
# [1] 0

# %%
param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(99991) # inicializo con mi primer semilla
# me quedo con por ejemplo 20 primos al azar
semillas_ensemble <- sample(primos, 10 )
print( semillas_ensemble )
# Out:
#  [1] 344417 905647 164371 908359 395287 271729 877771 102761 859423 246049

# %%
dfuture <- dataset[foto_mes %in% PARAM$future]
matriz_prediccion_future <- data.matrix(dfuture[, campos_buenos, with= FALSE])
predicciones_individuales <- list()
importancias_individuales <- list()
cat("Iniciando entrenamiento y predicción para el Ensemble con", length(semillas_ensemble), "semillas...\n")

for (sem in semillas_ensemble) {
    param_normalizado$seed <- sem # Fijar la semilla para esta corrida

    cat(paste("Entrenando modelo con semilla:", sem, "\n"))

    # Entrenar LightGBM
    modelo <- lgb.train(
        data= dtrain_final,
        param= param_normalizado
    )

    # Aplicar el modelo a los datos futuros (202106)
    pred <- predict(modelo, matriz_prediccion_future)

    # Guardar la predicción
    predicciones_individuales[[as.character(sem)]] <- pred

    tb_importancia_semilla <- as.data.table(lgb.importance(modelo))
    importancias_individuales[[as.character(sem)]] <- tb_importancia_semilla
}
# Out:
# Iniciando entrenamiento y predicción para el Ensemble con 10 semillas...
# Entrenando modelo con semilla: 344417
# Entrenando modelo con semilla: 905647
# Entrenando modelo con semilla: 164371
# Entrenando modelo con semilla: 908359
# Entrenando modelo con semilla: 395287
# Entrenando modelo con semilla: 271729
# Entrenando modelo con semilla: 877771
# Entrenando modelo con semilla: 102761
# Entrenando modelo con semilla: 859423
# Entrenando modelo con semilla: 246049

# %%
# 3.1. Promedio de predicciones (ENSEMBLE)
prediccion_ensemble <- Reduce("+", predicciones_individuales) / length(predicciones_individuales)

# 3.2. Crear tabla de predicción
tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes)]
tb_prediccion[, prob := prediccion_ensemble ]

# 3.3. Grabar la probabilidad (Opcional, para debug)
fwrite(tb_prediccion,
    file= "prediccion_final_4923_ensemble.txt",
    sep= "\t"
)

# %%
# 1. Consolidar todas las tablas de importancia individuales en una sola
df_importancias_consolidadas <- rbindlist(importancias_individuales, use.names = TRUE, fill = TRUE)

# 2. Calcular la Importancia Promedio por Feature
# Agrupamos por Feature y promediamos el valor de la importancia (Gain)
tb_importancia_ensemble <- df_importancias_consolidadas[,
    list(
        # Promediamos la métrica de importancia (Gain es la estándar)
        Gain_promedio = mean(Gain, na.rm = TRUE),
        # Opcional: Desviación estándar para medir la estabilidad de la importancia
        Gain_sd = sd(Gain, na.rm = TRUE)
    ),
    by = Feature]

# 3. Ordenar por la importancia promedio descendente
setorder(tb_importancia_ensemble, -Gain_promedio)


# 4. Guardar la importancia final del Ensemble
archivo_importancia_ensemble <- "impo_ensemble_4923.txt"

fwrite(tb_importancia_ensemble,
       file = archivo_importancia_ensemble,
       sep = "\t"
)

cat(paste("\nImportancia de variables del Ensemble guardada en:", archivo_importancia_ensemble, "\n"))
# Out:
# Importancia de variables del Ensemble guardada en: impo_ensemble_4923.txt

# %%
require( "data.table" )

# Rango de envíos a exportar (Tu rango deseado)
PARAM$cortes_kaggle <- seq(8500, 12000, by= 100)

# Crear la carpeta 'kaggle' si no existe
dir.create("kaggle", showWarnings = FALSE)

# 1. Ordenar el data.table de predicción una sola vez (por probabilidad)
setorder(tb_prediccion, -prob)

# 2. Loop para generar y exportar la submission para cada corte
cat("Iniciando la exportación de archivos Kaggle para", length(PARAM$cortes), "cortes...\n")
archivos_generados <- 0

# Creamos una copia de la tabla base para el loop
tb_export <- copy(tb_prediccion)

for (envios in PARAM$cortes_kaggle) {

    # 2a. Inicializar/Resetear la columna de predicción binaria
    tb_export[, Predicted := 0L]

    # 2b. Marcar como 1 (BAJA) solo a los N clientes con mayor probabilidad
    tb_export[1:envios, Predicted := 1L]

    # 2c. Definir el nombre del archivo
    # Usamos 'KA_C' para identificar que es un archivo de Corte
    archivo_kaggle <- paste0("./kaggle/4923_C", envios, ".csv")

    # 2d. Exportar la submission
    fwrite(tb_export[, .(numero_de_cliente, Predicted)],
           file = archivo_kaggle,
           sep = ",")

    archivos_generados <- archivos_generados + 1
}

# 3. Mensaje de Finalización
cat("\n--- TAREA FINALIZADA ---\n")
cat(paste("Se generaron", archivos_generados, "archivos de submission de Kaggle en la carpeta 'kaggle'.\n"))
# Out:
# Iniciando la exportación de archivos Kaggle para 71 cortes...
#
# --- TAREA FINALIZADA ---
# Se generaron 36 archivos de submission de Kaggle en la carpeta 'kaggle'.
